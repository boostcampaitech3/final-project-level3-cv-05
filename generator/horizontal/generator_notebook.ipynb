# %%
import os
from generate import generate
from drawer import image_generate
import json

for dir in ['results', 'results/images']:
    os.makedirs(dir, exist_ok=True)

idx = len(os.listdir('results/images'))
if os.path.exists('results/info.json'):
    with open('results/info.json', 'r', encoding="UTF-8") as j:
        json_object = json.load(j)
else:
    with open('sample.json', 'r', encoding="UTF-8") as j:
        json_object = json.load(j)

# %%
info = generate()
image, image_info, width, height = image_generate(info)
image_info
# Out:
# [{'category_id': 4,
#   'orientation': 'Horizontal',
#   'points': [[207, 214], [540, 214], [540, 254], [207, 254]],
#   'text': '장기이식코디네이터'},
#  {'category_id': 1,
#   'orientation': 'Horizontal',
#   'points': [[551, 205], [788, 205], [788, 254], [551, 254]],
#   'text': '김재성'},
#  {'category_id': 6,
#   'orientation': 'Horizontal',
#   'points': [[207, 264], [347, 264], [347, 300], [207, 300]],
#   'text': '마케팅팀'},
#  {'category_id': 5,
#   'orientation': 'Horizontal',
#   'points': [[45, 30], [298, 30], [298, 107], [45, 107]],
#   'text': '여석사역학원'},
#  'category_id',
#  'orientation',
#  'points',
#  'text',
#  {'category_id': 0,
#   'orientation': 'Horizontal',
#   'points': [[72, 397], [119, 397], [119, 416], [72, 416]],
#   'text': 'site  '},
#  {'category_id': 8,
#   'orientation': 'Horizontal',
#   'points': [[119, 397], [313, 397], [313, 417], [119, 417]],
#   'text': 'www.222.munso7.com'},
#  {'category_id': 0,
#   'orientation': 'Horizontal',
#   'points': [[541, 397], [598, 397], [598, 417], [541, 417]],
#   'text': 'Email  '},
#  {'category_id': 3,
#   'orientation': 'Horizontal',
#   'points': [[598, 397], [829, 397], [829, 419], [598, 419]],
#   'text': 'W-UkL2S3j@uracle.co.kr'},
#  {'category_id': 0,
#   'orientation': 'Horizontal',
#   'points': [[72, 366], [138, 366], [138, 386], [72, 386]],
#   'text': 'Phone  '},
#  {'category_id': 2,
#   'orientation': 'Horizontal',
#   'points': [[138, 366], [276, 366], [276, 386], [138, 386]],
#   'text': '621-8751-659'}]

# %%
# number of make images
number = 1000
for _ in range(number):
    info = generate()
    image, image_info, width, height = image_generate(info)
    json_object["images"].append({"width": width, "height": height, "file":f"{idx:04}.png", "id": idx})
    annotation = {"image_id":idx, "ocr":{"word":image_info}}
    json_object["annotations"].append(annotation)
    image.save(f'results/images/{idx:04}.png')
    idx += 1

with open('results/info.json', 'w', encoding="UTF-8") as j:
    json_string = json.dump(json_object,j, indent=2)

# %%
with open('results/info.json', 'r', encoding="UTF-8") as j:
    json_object = json.load(j)

# %%
json_object.keys()
# Out:
# dict_keys(['images', 'categories', 'annotations'])

# %%
json_object['annotations']
# Out:
# [{'image_id': 0,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[385, 221], [691, 221], [691, 260], [385, 260]],
#      'text': '감염관리전문간호사'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[234, 205], [375, 205], [375, 260], [234, 260]],
#      'text': '김예형'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[45, 35], [205, 35], [205, 71], [45, 71]],
#      'text': '중고폰마트'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[45, 8], [812, 8], [812, 30], [45, 30]],
#      'text': '인생에서 원하는 것을 엇기 위한 첫번째 단계는 내가 무엇을 원하는지 결정하는 것이다'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 394], [200, 394], [200, 417], [144, 417]],
#      'text': 'site) '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[200, 394], [386, 394], [386, 420], [200, 420]],
#      'text': 'www.jieum.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[610, 394], [685, 394], [685, 417], [610, 417]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[685, 394], [897, 394], [897, 413], [685, 413]],
#      'text': 'HGEbeqtzN@empas.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 363], [199, 363], [199, 386], [144, 386]],
#      'text': 'Call) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[199, 363], [329, 363], [329, 384], [199, 384]],
#      'text': '39-74-241'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[610, 363], [696, 363], [696, 386], [610, 386]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[696, 363], [840, 363], [840, 384], [696, 384]],
#      'text': '87-37-2069'}]}},
#  {'image_id': 1,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[523, 209], [708, 209], [708, 250], [523, 250]],
#      'text': '아이돌보미'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[720, 200], [855, 200], [855, 250], [720, 250]],
#      'text': '유선주'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[747, 260], [855, 260], [855, 300], [747, 300]],
#      'text': '직판팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[72, 30], [417, 30], [417, 109], [72, 109]],
#      'text': '행복을 더하다'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[72, 1], [369, 1], [369, 25], [72, 25]],
#      'text': '산다는것 그것은 치열한 전투이다. '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[108, 414], [277, 414], [277, 441], [108, 441]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[277, 414], [458, 414], [458, 438], [277, 438]],
#      'text': '571-34-60657'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[108, 377], [416, 377], [416, 402], [108, 402]],
#      'text': 'RbwbfV@cmcakorea.com'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[566, 377], [758, 377], [758, 402], [566, 402]],
#      'text': '4329.3845.887'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[108, 340], [284, 340], [284, 365], [108, 365]],
#      'text': '496.570.4745'}]}},
#  {'image_id': 2,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[732, 364], [846, 364], [846, 407], [732, 407]],
#      'text': '경찰관'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[540, 350], [720, 350], [720, 407], [540, 407]],
#      'text': '김경은'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[54, 30], [132, 30], [132, 99], [54, 99]],
#      'text': '이레'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 244], [249, 244], [249, 265], [99, 265]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[249, 244], [394, 244], [394, 263], [249, 263]],
#      'text': '437-72-69608'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 210], [145, 210], [145, 228], [99, 228]],
#      'text': 'site  '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[145, 210], [341, 210], [341, 232], [145, 232]],
#      'text': 'www.gongdosa.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[535, 210], [600, 210], [600, 228], [535, 228]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[600, 210], [881, 210], [881, 232], [600, 232]],
#      'text': 'BONoRC0kb0j@newmrg.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 179], [145, 179], [145, 197], [99, 197]],
#      'text': 'Fax  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[145, 179], [265, 179], [265, 198], [145, 198]],
#      'text': '77-54-7096'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[535, 179], [583, 179], [583, 197], [535, 197]],
#      'text': 'Call  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[583, 179], [701, 179], [701, 198], [583, 198]],
#      'text': '07-318-428'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 149], [170, 149], [170, 167], [99, 167]],
#      'text': 'Phone  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[170, 149], [313, 149], [313, 167], [170, 167]],
#      'text': '397-7366-676'}]}},
#  {'image_id': 3,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[519, 209], [675, 209], [675, 253], [519, 253]],
#      'text': '영업사원'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[298, 200], [508, 200], [508, 253], [298, 253]],
#      'text': '박상용'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[570, 161], [675, 161], [675, 200], [570, 200]],
#      'text': '전산실'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[642, 30], [819, 30], [819, 59], [642, 59]],
#      'text': 'Accent ESL'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[81, 392], [197, 392], [197, 415], [81, 415]],
#      'text': 'rappelz.com'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[531, 392], [808, 392], [808, 416], [531, 416]],
#      'text': 'ZOKc6AFVaDUj2@never.com'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[81, 359], [208, 359], [208, 381], [81, 381]],
#      'text': '259-6530-827'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[531, 359], [647, 359], [647, 380], [531, 380]],
#      'text': '4446-26-616'}]}},
#  {'image_id': 4,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[432, 208], [801, 208], [801, 251], [432, 251]],
#      'text': '소비자트렌드분석가'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[275, 200], [422, 200], [422, 251], [275, 251]],
#      'text': '강은수'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[693, 163], [801, 163], [801, 200], [693, 200]],
#      'text': '인사팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[655, 30], [819, 30], [819, 77], [655, 77]],
#      'text': '블랙라벨'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[454, 82], [819, 82], [819, 108], [454, 108]],
#      'text': '너무 고르는 자가 가장 나쁜 것을 갖는다.'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[126, 399], [186, 399], [186, 420], [126, 420]],
#      'text': 'Web) '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[186, 399], [329, 399], [329, 422], [186, 422]],
#      'text': 'mycare.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[558, 399], [628, 399], [628, 420], [558, 420]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[628, 399], [845, 399], [845, 422], [628, 422]],
#      'text': 'q282@beanent.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[126, 368], [178, 368], [178, 389], [126, 389]],
#      'text': 'Fax) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[178, 368], [321, 368], [321, 389], [178, 389]],
#      'text': '372.235.7387'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[558, 368], [638, 368], [638, 389], [558, 389]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[638, 368], [779, 368], [779, 389], [638, 389]],
#      'text': '21.7275.0686'}]}},
#  {'image_id': 5,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[135, 205], [279, 205], [279, 259], [135, 259]],
#      'text': '이기정'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[54, 35], [164, 35], [164, 67], [54, 67]],
#      'text': '엘씨인터내셔날'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[54, 72], [632, 72], [632, 95], [54, 95]],
#      'text': '날씬한 몸매를 갖고 싶다면 너의 음식을 배고픈 사람과 나누라.'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[117, 392], [290, 392], [290, 411], [117, 411]],
#      'text': 'www.imoso.co.kr'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[584, 392], [898, 392], [898, 414], [584, 414]],
#      'text': 'DADuNmxgdDJRkP@kckorea.co.kr'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[117, 362], [257, 362], [257, 381], [117, 381]],
#      'text': '47-3356-5692'}]}},
#  {'image_id': 6,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[90, 64], [285, 64], [285, 111], [90, 111]],
#      'text': '그린마케터'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[297, 55], [516, 55], [516, 111], [297, 111]],
#      'text': '정석열'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[415, 121], [514, 121], [514, 162], [415, 162]],
#      'text': '회계팀'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[117, 287], [452, 287], [452, 308], [117, 308]],
#      'text': '_kxcpyQo-qwzAV5@italo-moto.com'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[578, 287], [766, 287], [766, 308], [578, 308]],
#      'text': '(+266)7411-263-5744'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[117, 254], [295, 254], [295, 275], [117, 275]],
#      'text': '(+266)29-4629-9126'}]}},
#  {'image_id': 7,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[323, 76], [594, 76], [594, 119], [323, 119]],
#      'text': '교통행정처분상담자'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[606, 70], [711, 70], [711, 119], [606, 119]],
#      'text': '조원상'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[625, 32], [711, 32], [711, 70], [625, 70]],
#      'text': '전산실'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[90, 385], [234, 385], [234, 452], [90, 452]],
#      'text': '핑크아리'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 296], [251, 296], [251, 320], [99, 320]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[251, 296], [387, 296], [387, 318], [251, 318]],
#      'text': '446-63-79456'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 223], [157, 223], [157, 245], [99, 245]],
#      'text': 'Web. '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[157, 223], [384, 223], [384, 248], [157, 248]],
#      'text': 'www.robsoncamp.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[568, 223], [629, 223], [629, 245], [568, 245]],
#      'text': 'Email. '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[629, 223], [892, 223], [892, 248], [629, 248]],
#      'text': 'tuuVOC@hunoconsulting.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 187], [142, 187], [142, 209], [99, 209]],
#      'text': 'Fax. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[142, 187], [318, 187], [318, 211], [142, 211]],
#      'text': '(+677)80-024-591'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[568, 187], [613, 187], [613, 209], [568, 209]],
#      'text': 'Call. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[613, 187], [822, 187], [822, 211], [613, 211]],
#      'text': '(+677)202-5596-1981'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 151], [171, 151], [171, 173], [99, 173]],
#      'text': 'Phone. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[171, 151], [372, 151], [372, 175], [171, 175]],
#      'text': '(+677)0460-309-471'}]}},
#  {'image_id': 8,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[382, 84], [627, 84], [627, 126], [382, 126]],
#      'text': '방문목욕도우미'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[639, 70], [783, 70], [783, 126], [639, 126]],
#      'text': '김영우'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[681, 31], [783, 31], [783, 70], [681, 70]],
#      'text': '지원팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[45, 380], [237, 380], [237, 407], [45, 407]],
#      'text': '주식회사 원더플레이스 온라인'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 294], [203, 294], [203, 316], [45, 316]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[203, 294], [342, 294], [342, 313], [203, 313]],
#      'text': '396-66-86726'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 225], [91, 225], [91, 244], [45, 244]],
#      'text': 'site  '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[91, 225], [270, 225], [270, 248], [91, 248]],
#      'text': 'www.fitlogo.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[488, 225], [557, 225], [557, 243], [488, 243]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[557, 225], [862, 225], [862, 246], [557, 246]],
#      'text': 'rY_tv2zm2Gi@cafe24mail.com'}]}},
#  {'image_id': 9,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[438, 205], [657, 205], [657, 254], [438, 254]],
#      'text': '김은구'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[72, 438], [317, 438], [317, 458], [72, 458]],
#      'text': 'I6_m43YdJ_@iuma.co.kr'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[506, 438], [734, 438], [734, 460], [506, 460]],
#      'text': '(+966)622-8917-5110'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[72, 404], [261, 404], [261, 426], [72, 426]],
#      'text': '(+966)51-54-9969'}]}},
#  {'image_id': 10,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[466, 211], [564, 211], [564, 246], [466, 246]],
#      'text': '사냥꾼'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[575, 200], [792, 200], [792, 246], [575, 246]],
#      'text': '홍실이'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[54, 30], [167, 30], [167, 87], [54, 87]],
#      'text': '동일전산'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[54, 92], [649, 92], [649, 119], [54, 119]],
#      'text': '탐욕은 일체를 얻고자 욕심내어서 도리어 모든 것을 잃어버린다.'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[117, 417], [273, 417], [273, 442], [117, 442]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[273, 417], [407, 417], [407, 439], [273, 439]],
#      'text': '924-52-03019'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[117, 347], [297, 347], [297, 369], [117, 369]],
#      'text': 'www.chzero.com'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[560, 347], [717, 347], [717, 373], [560, 373]],
#      'text': 'ku@sunjin.net'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[117, 310], [304, 310], [304, 336], [117, 336]],
#      'text': '(+383)48-926-9662'}]}},
#  {'image_id': 11,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[564, 204], [675, 204], [675, 246], [564, 246]],
#      'text': '프런트'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[418, 200], [553, 200], [553, 246], [418, 246]],
#      'text': '이대우'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[505, 256], [675, 256], [675, 295], [505, 295]],
#      'text': '교육연수팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[54, 30], [125, 30], [125, 57], [54, 57]],
#      'text': '케이에스피플'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[54, 62], [361, 62], [361, 85], [54, 85]],
#      'text': '의욕적인 목표가 인생을 즐겁게 한다.'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 420], [183, 420], [183, 442], [45, 442]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[183, 420], [339, 420], [339, 439], [183, 439]],
#      'text': '610-06-41668'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[45, 353], [250, 353], [250, 376], [45, 376]],
#      'text': 'www.kissingyou.co.kr'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[493, 353], [675, 353], [675, 376], [493, 376]],
#      'text': 'PsX@hanyang.ac.kr'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[45, 321], [287, 321], [287, 342], [45, 342]],
#      'text': '(+47 79)333-6941-112'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[493, 321], [735, 321], [735, 342], [493, 342]],
#      'text': '(+47 79)343-583-0339'}]}},
#  {'image_id': 12,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[779, 215], [855, 215], [855, 262], [779, 262]],
#      'text': '교황'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[625, 205], [769, 205], [769, 262], [625, 262]],
#      'text': '한경수'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[741, 272], [855, 272], [855, 317], [741, 317]],
#      'text': '관재팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[589, 35], [828, 35], [828, 66], [589, 66]],
#      'text': '주식회사 그린라이온'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 441], [105, 441], [105, 462], [45, 462]],
#      'text': 'Web) '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[105, 441], [287, 441], [287, 465], [105, 465]],
#      'text': 'www.heygift.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[498, 441], [566, 441], [566, 462], [498, 462]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[566, 441], [888, 441], [888, 464], [566, 464]],
#      'text': 'Fyy7WelaA@khanindustries.net'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 410], [124, 410], [124, 431], [45, 431]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[124, 410], [340, 410], [340, 431], [124, 431]],
#      'text': '(+220)263-508-985'}]}},
#  {'image_id': 13,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[126, 200], [302, 200], [302, 248], [126, 248]],
#      'text': '이보라미'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[81, 35], [172, 35], [172, 82], [81, 82]],
#      'text': '마미맘'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 424], [193, 424], [193, 448], [45, 448]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[193, 424], [339, 424], [339, 444], [193, 444]],
#      'text': '111-31-22962'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 353], [116, 353], [116, 375], [45, 375]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[116, 353], [401, 353], [401, 378], [116, 378]],
#      'text': 'JwHTIj6kZ8Ol@1-inc.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[490, 353], [543, 353], [543, 375], [490, 375]],
#      'text': 'Fax) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[543, 353], [725, 353], [725, 375], [543, 375]],
#      'text': '0487-9951-625'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 322], [127, 322], [127, 344], [45, 344]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[127, 322], [295, 322], [295, 342], [127, 342]],
#      'text': '018-4525-4181'}]}},
#  {'image_id': 14,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[387, 210], [702, 210], [702, 249], [387, 249]],
#      'text': '교통행정처분상담자'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[239, 200], [377, 200], [377, 249], [239, 249]],
#      'text': '임지민'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[239, 162], [414, 162], [414, 200], [239, 200]],
#      'text': '내부감사팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[54, 35], [243, 35], [243, 79], [54, 79]],
#      'text': '시디네'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[54, 84], [420, 84], [420, 106], [54, 106]],
#      'text': '우리는 영혼을 움직이는 침묵이 필요하다.'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[108, 424], [276, 424], [276, 446], [108, 446]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[276, 424], [428, 424], [428, 445], [276, 445]],
#      'text': '910-12-27145'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[108, 355], [190, 355], [190, 376], [108, 376]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[190, 355], [554, 355], [554, 379], [190, 379]],
#      'text': 'q7BlSjMpyz@raboumoutlet.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[550, 355], [610, 355], [610, 376], [550, 376]],
#      'text': 'Fax : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[610, 355], [864, 355], [864, 378], [610, 378]],
#      'text': '(+90 392)94-360-7766'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[108, 322], [199, 322], [199, 343], [108, 343]],
#      'text': 'Phone : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[199, 322], [431, 322], [431, 345], [199, 345]],
#      'text': '(+90 392)52-81-8617'}]}},
#  {'image_id': 15,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[270, 205], [481, 205], [481, 258], [270, 258]],
#      'text': '정종혁'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[63, 439], [127, 439], [127, 459], [63, 459]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[127, 439], [284, 439], [284, 464], [127, 464]],
#      'text': 'IAbF@oregin.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[532, 439], [582, 439], [582, 459], [532, 459]],
#      'text': 'Call  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[582, 439], [777, 439], [777, 461], [582, 461]],
#      'text': '(+688)00-4497-398'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[63, 406], [137, 406], [137, 426], [63, 426]],
#      'text': 'Phone  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[137, 406], [328, 406], [328, 428], [137, 428]],
#      'text': '(+688)776-346-614'}]}},
#  {'image_id': 16,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[796, 66], [855, 66], [855, 105], [796, 105]],
#      'text': 'SM'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[639, 50], [786, 50], [786, 105], [639, 105]],
#      'text': '김현태'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[639, 10], [744, 10], [744, 50], [639, 50]],
#      'text': '지원팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[81, 385], [306, 385], [306, 450], [81, 450]],
#      'text': '유니콘 스튜디오'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[81, 455], [682, 455], [682, 480], [81, 480]],
#      'text': '타인의 결점은 우리들의 눈앞에 있고, 자신의 결점은 우리의 등 뒤에 있다.'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 295], [283, 295], [283, 318], [144, 318]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[283, 295], [424, 295], [424, 315], [283, 315]],
#      'text': '129-36-54730'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 230], [208, 230], [208, 250], [144, 250]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[208, 230], [455, 230], [455, 251], [208, 251]],
#      'text': 'hLPc7A@autotrade.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[600, 230], [675, 230], [675, 250], [600, 250]],
#      'text': 'Phone : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[675, 230], [891, 230], [891, 252], [675, 252]],
#      'text': '(+599 9)192.3198.601'}]}},
#  {'image_id': 17,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[317, 369], [465, 369], [465, 413], [317, 413]],
#      'text': '도축업자'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[99, 360], [306, 360], [306, 413], [99, 413]],
#      'text': '장치원'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[299, 319], [464, 319], [464, 360], [299, 360]],
#      'text': '내부감사팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[90, 30], [305, 30], [305, 106], [90, 106]],
#      'text': '퀼트베이스'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[90, 3], [497, 3], [497, 25], [90, 25]],
#      'text': '나를 죽이지 못한 것은 끝내 나를 강하게 만들리라.'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[63, 218], [115, 218], [115, 237], [63, 237]],
#      'text': 'site : '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[115, 218], [271, 218], [271, 242], [115, 242]],
#      'text': 'www.jungbna.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[507, 218], [569, 218], [569, 238], [507, 238]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[569, 218], [771, 218], [771, 242], [569, 242]],
#      'text': 'Zou@153shopping.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[63, 187], [113, 187], [113, 206], [63, 206]],
#      'text': 'Fax : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[113, 187], [268, 187], [268, 207], [113, 207]],
#      'text': '254-5701-9665'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[507, 187], [578, 187], [578, 207], [507, 207]],
#      'text': 'Phone : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[578, 187], [716, 187], [716, 207], [578, 207]],
#      'text': '12-2322-7367'}]}},
#  {'image_id': 18,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[180, 73], [439, 73], [439, 113], [180, 113]],
#      'text': '관광통역안내원'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[449, 60], [602, 60], [602, 113], [449, 113]],
#      'text': '장대환'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[491, 21], [602, 21], [602, 60], [491, 60]],
#      'text': '채권팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[63, 380], [194, 380], [194, 421], [63, 421]],
#      'text': '프레임샵'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[63, 426], [421, 426], [421, 453], [63, 453]],
#      'text': '고백한 죄의 반은 용서 받은 것이다.'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[72, 253], [140, 253], [140, 273], [72, 273]],
#      'text': 'Email. '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[140, 253], [373, 253], [373, 277], [140, 277]],
#      'text': 'EnzyI@slacknsoft.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[526, 253], [573, 253], [573, 273], [526, 273]],
#      'text': 'Fax. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[573, 253], [787, 253], [787, 276], [573, 276]],
#      'text': '(+508)742-629-3210'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[72, 220], [121, 220], [121, 240], [72, 240]],
#      'text': 'Call. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[121, 220], [335, 220], [335, 243], [121, 243]],
#      'text': '(+508)988-8161-877'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[526, 220], [603, 220], [603, 240], [526, 240]],
#      'text': 'Phone. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[603, 220], [804, 220], [804, 243], [603, 243]],
#      'text': '(+508)5279-82-756'}]}},
#  {'image_id': 19,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[225, 214], [470, 214], [470, 257], [225, 257]],
#      'text': '지방자치단체장'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[482, 205], [689, 205], [689, 257], [482, 257]],
#      'text': '윤준연'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[582, 267], [687, 267], [687, 309], [582, 309]],
#      'text': '지원팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[603, 35], [855, 35], [855, 120], [603, 120]],
#      'text': '주신컨설팅'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[90, 441], [246, 441], [246, 466], [90, 466]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[246, 441], [380, 441], [380, 463], [246, 463]],
#      'text': '060-30-88210'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[90, 403], [171, 403], [171, 424], [90, 424]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[171, 403], [409, 403], [409, 429], [171, 429]],
#      'text': 'e2W@asyoukorea.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[522, 403], [586, 403], [586, 424], [522, 424]],
#      'text': 'Call : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[586, 403], [742, 403], [742, 425], [586, 425]],
#      'text': '5710-4004-9090'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[90, 369], [179, 369], [179, 390], [90, 390]],
#      'text': 'Phone : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[179, 369], [291, 369], [291, 391], [179, 391]],
#      'text': '39-034-500'}]}},
#  {'image_id': 20,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[431, 362], [773, 362], [773, 407], [431, 407]],
#      'text': '병원아동생활정문가'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[243, 355], [420, 355], [420, 407], [243, 407]],
#      'text': '최민영'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[243, 315], [413, 315], [413, 355], [243, 355]],
#      'text': '노사협력팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[478, 35], [810, 35], [810, 84], [478, 84]],
#      'text': '주식회사 더에코랩'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[422, 5], [810, 5], [810, 30], [422, 30]],
#      'text': '마음이 좁은 자는 생각이 극단에 흐른다.'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 234], [164, 234], [164, 252], [99, 252]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[164, 234], [498, 234], [498, 256], [164, 256]],
#      'text': 'rh-C2pJPrGkTw@allthatview.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[533, 234], [579, 234], [579, 252], [533, 252]],
#      'text': 'Call  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[579, 234], [727, 234], [727, 252], [579, 252]],
#      'text': '9150-054-048'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[99, 205], [173, 205], [173, 223], [99, 223]],
#      'text': 'Phone  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[173, 205], [308, 205], [308, 223], [173, 223]],
#      'text': '03-952-8266'}]}},
#  {'image_id': 21,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[198, 291], [442, 291], [442, 336], [198, 336]],
#      'text': '동물원큐레이터'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[452, 280], [613, 280], [613, 336], [452, 336]],
#      'text': '채명석'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[693, 385], [837, 385], [837, 459], [693, 459]],
#      'text': '윙진'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 146], [191, 146], [191, 168], [45, 168]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[191, 146], [347, 146], [347, 165], [191, 165]],
#      'text': '196-56-91118'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 81], [110, 81], [110, 100], [45, 100]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[110, 81], [239, 81], [239, 104], [110, 104]],
#      'text': 'yDi@gsang.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[497, 81], [545, 81], [545, 100], [497, 100]],
#      'text': 'Fax : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[545, 81], [740, 81], [740, 102], [545, 102]],
#      'text': '(+225)98.8131.281'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 50], [120, 50], [120, 69], [45, 69]],
#      'text': 'Phone : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[120, 50], [341, 50], [341, 71], [120, 71]],
#      'text': '(+225)2514.832.2580'}]}},
#  {'image_id': 22,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[615, 219], [729, 219], [729, 262], [615, 262]],
#      'text': '연기자'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[425, 205], [605, 205], [605, 262], [425, 262]],
#      'text': '고민성'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[425, 272], [635, 272], [635, 312], [425, 312]],
#      'text': '대리점지원팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[63, 30], [225, 30], [225, 82], [63, 82]],
#      'text': '스마일'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[72, 388], [387, 388], [387, 410], [72, 410]],
#      'text': 'VSjo-Gc1c2acIpS@akbomonster.com'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[507, 388], [622, 388], [622, 406], [507, 406]],
#      'text': '129-320-564'}]}},
#  {'image_id': 23,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[512, 200], [729, 200], [729, 247], [512, 247]],
#      'text': '위석준'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[72, 30], [252, 30], [252, 63], [72, 63]],
#      'text': '주식회사 원밀리모어'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[72, 430], [199, 430], [199, 454], [72, 454]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[199, 430], [327, 430], [327, 450], [199, 450]],
#      'text': '890-90-64682'},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[72, 399], [293, 399], [293, 420], [72, 420]],
#      'text': 'aLRATP@aaoceanic.co.kr'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[507, 399], [643, 399], [643, 419], [507, 419]],
#      'text': '7996-4778-640'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[72, 369], [194, 369], [194, 389], [72, 389]],
#      'text': '2250-177-570'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[507, 369], [642, 369], [642, 389], [507, 389]],
#      'text': '0679-600-5183'}]}},
#  {'image_id': 24,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[153, 65], [336, 65], [336, 119], [153, 119]],
#      'text': '윤일형'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[63, 380], [234, 380], [234, 407], [63, 407]],
#      'text': '이에스인재교육연구소'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 301], [287, 301], [287, 321], [135, 321]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[287, 301], [437, 301], [437, 320], [287, 320]],
#      'text': '332-04-53260'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 239], [200, 239], [200, 258], [135, 258]],
#      'text': 'Web : '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[200, 239], [422, 239], [422, 261], [200, 261]],
#      'text': 'www.ny-sponge.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[573, 239], [645, 239], [645, 258], [573, 258]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[645, 239], [885, 239], [885, 254], [645, 254]],
#      'text': 'dwsXkOY4WosPf@reachapp.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 210], [218, 210], [218, 229], [135, 229]],
#      'text': 'Phone : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[218, 210], [335, 210], [335, 229], [218, 229]],
#      'text': '70-29-6112'}]}},
#  {'image_id': 25,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[370, 210], [675, 210], [675, 249], [370, 249]],
#      'text': '디지털포렌식수사관'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[192, 200], [359, 200], [359, 249], [192, 249]],
#      'text': '윤은정'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[90, 30], [358, 30], [358, 97], [90, 97]],
#      'text': '에스유 컴퍼니'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 436], [184, 436], [184, 455], [45, 455]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[184, 436], [306, 436], [306, 454], [184, 454]],
#      'text': '138-33-65164'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 370], [93, 370], [93, 388], [45, 388]],
#      'text': 'site  '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[93, 370], [229, 370], [229, 394], [93, 394]],
#      'text': 'hyperdigm.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[492, 370], [554, 370], [554, 388], [492, 388]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[554, 370], [789, 370], [789, 394], [554, 394]],
#      'text': 'OWvsvxjlHIx@babyu.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 341], [93, 341], [93, 359], [45, 359]],
#      'text': 'Fax  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[93, 341], [198, 341], [198, 359], [93, 359]],
#      'text': '889.616.503'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[492, 341], [561, 341], [561, 359], [492, 359]],
#      'text': 'Phone  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[561, 341], [671, 341], [671, 359], [561, 359]],
#      'text': '8792.06.904'}]}},
#  {'image_id': 26,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[366, 217], [477, 217], [477, 260], [366, 260]],
#      'text': '부사장'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[489, 205], [648, 205], [648, 260], [489, 260]],
#      'text': '송진경'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[368, 270], [584, 270], [584, 311], [368, 311]],
#      'text': '대리점지원팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[263, 30], [855, 30], [855, 116], [263, 116]],
#      'text': '바로인테리어가구'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[420, 0], [855, 0], [855, 25], [420, 25]],
#      'text': '아침에 당신을 벌떡 깨울 수 있는 꿈을 가져야 한다.'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 425], [206, 425], [206, 450], [45, 450]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[206, 425], [370, 425], [370, 448], [206, 448]],
#      'text': '105-19-44567'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[45, 344], [242, 344], [242, 372], [45, 372]],
#      'text': 'ph.koaplaza.com'},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[499, 344], [752, 344], [752, 370], [499, 370]],
#      'text': '(+850)996-932-1637'}]}},
#  {'image_id': 27,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[322, 209], [431, 209], [431, 253], [322, 253]],
#      'text': '사육사'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[441, 200], [648, 200], [648, 253], [441, 253]],
#      'text': '고래경'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[546, 263], [648, 263], [648, 305], [546, 305]],
#      'text': '채권팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[662, 30], [846, 30], [846, 118], [662, 118]],
#      'text': '호이키친'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[358, 1], [846, 1], [846, 25], [358, 25]],
#      'text': '오랫동안 꿈을 그리는 사람은 마침내 그 꿈을 닮아간다.'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[54, 431], [219, 431], [219, 457], [54, 457]],
#      'text': '사업자등록번호 : '},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[219, 431], [386, 431], [386, 455], [219, 455]],
#      'text': '084-33-93983'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[54, 360], [102, 360], [102, 384], [54, 384]],
#      'text': 'Fax. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[102, 360], [348, 360], [348, 385], [102, 385]],
#      'text': '(+856)835-9314-1478'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[519, 360], [571, 360], [571, 384], [519, 384]],
#      'text': 'Call. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[571, 360], [771, 360], [771, 385], [571, 385]],
#      'text': '(+856)98-96-850'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[54, 325], [132, 325], [132, 349], [54, 349]],
#      'text': 'Phone. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[132, 325], [388, 325], [388, 350], [132, 350]],
#      'text': '(+856)3690-2673-402'}]}},
#  {'image_id': 28,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[144, 50], [351, 50], [351, 99], [144, 99]],
#      'text': '김수현'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[54, 380], [162, 380], [162, 409], [54, 409]],
#      'text': '하얀토끼'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[54, 352], [508, 352], [508, 375], [54, 375]],
#      'text': '생각하는 대로 살지 못하면 사는 대로 생각한다.'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 262], [194, 262], [194, 283], [144, 283]],
#      'text': 'site) '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[194, 262], [328, 262], [328, 280], [194, 280]],
#      'text': 'www.anaun.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[613, 262], [679, 262], [679, 283], [613, 283]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[679, 262], [897, 262], [897, 278], [679, 278]],
#      'text': '_p4gYGALDs@orfeostory.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 229], [192, 229], [192, 250], [144, 250]],
#      'text': 'Fax) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[192, 229], [374, 229], [374, 250], [192, 250]],
#      'text': '(+298)654-47-4620'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[613, 229], [663, 229], [663, 250], [613, 250]],
#      'text': 'Call) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[663, 229], [823, 229], [823, 250], [663, 250]],
#      'text': '(+298)11-30-216'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 196], [219, 196], [219, 217], [144, 217]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[219, 196], [434, 196], [434, 217], [219, 217]],
#      'text': '(+298)0971-9514-0403'}]}},
#  {'image_id': 29,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[393, 207], [729, 207], [729, 252], [393, 252]],
#      'text': '호텔레비뉴매니저'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
# ...
#      'points': [[507, 263], [576, 263], [576, 282], [507, 282]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[576, 263], [816, 263], [816, 287], [576, 287]],
#      'text': 'MeU7JymoUc@hr.re.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 233], [93, 233], [93, 253], [45, 253]],
#      'text': 'Fax  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[93, 233], [207, 233], [207, 253], [93, 253]],
#      'text': '89.666.353'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[507, 233], [557, 233], [557, 252], [507, 252]],
#      'text': 'Call  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[557, 233], [697, 233], [697, 253], [557, 253]],
#      'text': '58.4910.5083'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[45, 203], [123, 203], [123, 222], [45, 222]],
#      'text': 'Phone  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[123, 203], [237, 203], [237, 223], [123, 223]],
#      'text': '90.62.8702'}]}},
#  {'image_id': 990,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[518, 205], [702, 205], [702, 257], [518, 257]],
#      'text': '오재경'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[528, 30], [810, 30], [810, 93], [528, 93]],
#      'text': '헬스파라다이스'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[556, 3], [810, 3], [810, 25], [556, 25]],
#      'text': '문제아 뒤에는 문제부모가 있다.'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 418], [209, 418], [209, 443], [144, 443]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[209, 418], [495, 418], [495, 443], [209, 443]],
#      'text': 'EaTiRcnWhT5@gnsystem.net'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[602, 418], [650, 418], [650, 443], [602, 443]],
#      'text': 'Call) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[650, 418], [865, 418], [865, 443], [650, 443]],
#      'text': '(+256)8368-06-0164'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 381], [219, 381], [219, 406], [144, 406]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[219, 381], [450, 381], [450, 406], [219, 406]],
#      'text': '(+256)808-2464-6522'}]}},
#  {'image_id': 991,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[618, 213], [738, 213], [738, 262], [618, 262]],
#      'text': '건축가'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[441, 205], [607, 205], [607, 262], [441, 262]],
#      'text': '권정희'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[442, 272], [544, 272], [544, 314], [442, 314]],
#      'text': '전산실'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[81, 30], [364, 30], [364, 76], [81, 76]],
#      'text': '삼청화 대학로'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[117, 400], [182, 400], [182, 420], [117, 420]],
#      'text': 'Web : '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[182, 400], [386, 400], [386, 420], [182, 420]],
#      'text': 'www.aero4me.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[549, 400], [625, 400], [625, 420], [549, 420]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[625, 400], [893, 400], [893, 422], [625, 422]],
#      'text': '6upNvhf1A@woorimfmg.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[117, 369], [171, 369], [171, 388], [117, 388]],
#      'text': 'Fax : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[171, 369], [315, 369], [315, 389], [171, 389]],
#      'text': '979-164-6892'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[549, 369], [632, 369], [632, 388], [549, 388]],
#      'text': 'Phone : '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[632, 369], [777, 369], [777, 389], [632, 389]],
#      'text': '24-8741-7335'}]}},
#  {'image_id': 992,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[135, 210], [415, 210], [415, 253], [135, 253]],
#      'text': '음성언어치료사'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[426, 200], [663, 200], [663, 253], [426, 253]],
#      'text': '권우형'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[557, 162], [662, 162], [662, 200], [557, 200]],
#      'text': '광고팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[643, 35], [846, 35], [846, 116], [643, 116]],
#      'text': '작은설렘'},
#     {'category_id': 10,
#      'orientation': 'Horizontal',
#      'points': [[124, 7], [846, 7], [846, 30], [124, 30]],
#      'text': '일과 오락이 규칙적으로 교대하면서 서로 조화를 이루면 생활이 즐거워진다.'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[90, 397], [142, 397], [142, 419], [90, 419]],
#      'text': 'site) '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[142, 397], [263, 397], [263, 416], [142, 416]],
#      'text': 'ritzvill.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[539, 397], [606, 397], [606, 419], [539, 419]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[606, 397], [810, 397], [810, 416], [606, 416]],
#      'text': 'V7sclvIZDtGlI@lof.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[90, 368], [141, 368], [141, 390], [90, 390]],
#      'text': 'Call) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[141, 368], [262, 368], [262, 386], [141, 386]],
#      'text': '92-6444-094'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[539, 368], [616, 368], [616, 390], [539, 390]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[616, 368], [737, 368], [737, 386], [616, 386]],
#      'text': '780-05-1712'}]}},
#  {'image_id': 993,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[296, 383], [452, 383], [452, 426], [296, 426]],
#      'text': '언어학자'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[72, 375], [285, 375], [285, 426], [72, 426]],
#      'text': '김예림'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[651, 30], [819, 30], [819, 80], [651, 80]],
#      'text': '소라앤코'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[81, 254], [131, 254], [131, 279], [81, 279]],
#      'text': 'Fax) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[131, 254], [244, 254], [244, 278], [131, 278]],
#      'text': '48-16-1162'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[549, 254], [626, 254], [626, 279], [549, 279]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[626, 254], [745, 254], [745, 278], [626, 278]],
#      'text': '440-84-239'}]}},
#  {'image_id': 994,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[467, 84], [633, 84], [633, 127], [467, 127]],
#      'text': 'PC정비사'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[645, 70], [846, 70], [846, 127], [645, 127]],
#      'text': '최현영'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[63, 385], [218, 385], [218, 462], [63, 462]],
#      'text': '이프'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 249], [203, 249], [203, 275], [135, 275]],
#      'text': 'Web) '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[203, 249], [449, 249], [449, 272], [203, 272]],
#      'text': 'www.chamzone.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[567, 249], [649, 249], [649, 275], [567, 275]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[649, 249], [899, 249], [899, 270], [649, 270]],
#      'text': '1rvskWaisrYo@2424.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 214], [193, 214], [193, 240], [135, 240]],
#      'text': 'Fax) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[193, 214], [357, 214], [357, 237], [193, 237]],
#      'text': '074-8268-511'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[567, 214], [629, 214], [629, 240], [567, 240]],
#      'text': 'Call) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[629, 214], [773, 214], [773, 237], [629, 237]],
#      'text': '349-46-823'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 179], [227, 179], [227, 205], [135, 205]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[227, 179], [416, 179], [416, 202], [227, 202]],
#      'text': '0988-1229-7911'}]}},
#  {'image_id': 995,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[462, 213], [747, 213], [747, 256], [462, 256]],
#      'text': '호텔레비뉴매니저'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[293, 200], [450, 200], [450, 256], [293, 256]],
#      'text': '송다희'},
#     {'category_id': 6,
#      'orientation': 'Horizontal',
#      'points': [[295, 160], [454, 160], [454, 200], [295, 200]],
#      'text': '교육연수팀'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[538, 35], [828, 35], [828, 102], [538, 102]],
#      'text': '석세스가이드'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[90, 393], [140, 393], [140, 414], [90, 414]],
#      'text': 'site  '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[140, 393], [361, 393], [361, 418], [140, 418]],
#      'text': 'www.gongjuson.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[535, 393], [603, 393], [603, 414], [535, 414]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[603, 393], [894, 393], [894, 411], [603, 411]],
#      'text': 'ZJNuR3gDXVvy0p@apparelbase.com'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[90, 361], [142, 361], [142, 382], [90, 382]],
#      'text': 'Call  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[142, 361], [258, 361], [258, 381], [142, 381]],
#      'text': '353.15.954'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[535, 361], [614, 361], [614, 381], [535, 381]],
#      'text': 'Phone  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[614, 361], [756, 361], [756, 381], [614, 381]],
#      'text': '8078.33.2368'}]}},
#  {'image_id': 996,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[612, 50], [756, 50], [756, 104], [612, 104]],
#      'text': '이지훈'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[144, 285], [221, 285], [221, 306], [144, 306]],
#      'text': 'Email : '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[221, 285], [528, 285], [528, 310], [221, 310]],
#      'text': 'ymniyLKm5Xk1Xid@ative.kr'}]}},
#  {'image_id': 997,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[441, 222], [508, 222], [508, 261], [441, 261]],
#      'text': '연출자'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[520, 205], [693, 205], [693, 261], [520, 261]],
#      'text': '이원빈'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[63, 414], [127, 414], [127, 437], [63, 437]],
#      'text': 'Email. '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[127, 414], [294, 414], [294, 438], [127, 438]],
#      'text': 'SQL@kaiem.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[500, 414], [574, 414], [574, 437], [500, 437]],
#      'text': 'Phone. '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[574, 414], [772, 414], [772, 438], [574, 438]],
#      'text': '(+263)705.901.302'}]}},
#  {'image_id': 998,
#   'ocr': {'word': [{'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[162, 200], [325, 200], [325, 252], [162, 252]],
#      'text': '민영선'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[634, 30], [828, 30], [828, 113], [634, 113]],
#      'text': '대미콜렉션'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[126, 392], [169, 392], [169, 412], [126, 412]],
#      'text': 'site  '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[169, 392], [372, 392], [372, 412], [169, 412]],
#      'text': 'www.dreamdrim.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[583, 392], [641, 392], [641, 412], [583, 412]],
#      'text': 'Email  '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[641, 392], [850, 392], [850, 416], [641, 416]],
#      'text': 'Rfg1@interscope.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[126, 360], [195, 360], [195, 380], [126, 380]],
#      'text': 'Phone  '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[195, 360], [356, 360], [356, 380], [195, 380]],
#      'text': '2741-7381-7736'}]}},
#  {'image_id': 999,
#   'ocr': {'word': [{'category_id': 4,
#      'orientation': 'Horizontal',
#      'points': [[356, 212], [516, 212], [516, 259], [356, 259]],
#      'text': '신문기자'},
#     {'category_id': 1,
#      'orientation': 'Horizontal',
#      'points': [[198, 200], [345, 200], [345, 259], [198, 259]],
#      'text': '이응재'},
#     {'category_id': 5,
#      'orientation': 'Horizontal',
#      'points': [[45, 35], [121, 35], [121, 88], [45, 88]],
#      'text': '포니애'},
#     'category_id',
#     'orientation',
#     'points',
#     'text',
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 387], [198, 387], [198, 410], [135, 410]],
#      'text': 'Web) '},
#     {'category_id': 8,
#      'orientation': 'Horizontal',
#      'points': [[198, 387], [423, 387], [423, 413], [198, 413]],
#      'text': 'englishfriend.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[602, 387], [678, 387], [678, 410], [602, 410]],
#      'text': 'Email) '},
#     {'category_id': 3,
#      'orientation': 'Horizontal',
#      'points': [[678, 387], [888, 387], [888, 401], [678, 401]],
#      'text': 'EQhGh3Z0LoMO@scif.co.kr'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[135, 353], [191, 353], [191, 376], [135, 376]],
#      'text': 'Fax) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[191, 353], [443, 353], [443, 376], [191, 376]],
#      'text': '(+1 784)6543-69-692'},
#     {'category_id': 0,
#      'orientation': 'Horizontal',
#      'points': [[602, 353], [688, 353], [688, 376], [602, 376]],
#      'text': 'Phone) '},
#     {'category_id': 2,
#      'orientation': 'Horizontal',
#      'points': [[688, 353], [890, 353], [890, 372], [688, 372]],
#      'text': '(+1 784)47-3246-6589'}]}},
#  ...]
