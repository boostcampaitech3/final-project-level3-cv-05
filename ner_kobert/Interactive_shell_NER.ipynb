# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import json
import pickle
import torch
from gluonnlp.data import SentencepieceTokenizer
from model.net import KobertCRF
from data_utils.utils import Config
from data_utils.vocab_tokenizer import Tokenizer
from data_utils.pad_sequence import keras_pad_fn
from pathlib import Path
# Out:
# 2022-06-02 00:50:48.284083: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/ocr_new/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-02 00:50:48.284123: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /opt/conda/envs/ocr_new/lib/python3.8/site-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
class DecoderFromNamedEntitySequence():
    def __init__(self, tokenizer, index_to_ner):
        self.tokenizer = tokenizer
        self.index_to_ner = index_to_ner

    def __call__(self, list_of_input_ids, list_of_pred_ids):
        input_token = self.tokenizer.decode_token_ids(list_of_input_ids)[0]
        pred_ner_tag = [self.index_to_ner[pred_id] for pred_id in list_of_pred_ids[0]]

        # ----------------------------- parsing list_of_ner_word ----------------------------- #
        list_of_ner_word = []
        entity_word, entity_tag, prev_entity_tag = "", "", ""
        for i, pred_ner_tag_str in enumerate(pred_ner_tag):
            if "B-" in pred_ner_tag_str:
                entity_tag = pred_ner_tag_str[-3:]

                if prev_entity_tag != entity_tag and prev_entity_tag != "":
                    list_of_ner_word.append({"word": entity_word.replace("▁", " "), "tag": prev_entity_tag, "prob": None})

                entity_word = input_token[i]
                prev_entity_tag = entity_tag
            elif "I-"+entity_tag in pred_ner_tag_str:
                entity_word += input_token[i]
            else:
                if entity_word != "" and entity_tag != "":
                    list_of_ner_word.append({"word":entity_word.replace("▁", " "), "tag":entity_tag, "prob":None})
                entity_word, entity_tag, prev_entity_tag = "", "", ""


        # ----------------------------- parsing decoding_ner_sentence ----------------------------- #
        decoding_ner_sentence = ""
        is_prev_entity = False
        prev_entity_tag = ""
        is_there_B_before_I = False

        for i, (token_str, pred_ner_tag_str) in enumerate(zip(input_token, pred_ner_tag)):
            if i == 0 or i == len(pred_ner_tag)-1: # remove [CLS], [SEP]
                continue
            token_str = token_str.replace('▁', ' ')  # '▁' 토큰을 띄어쓰기로 교체

            if 'B-' in pred_ner_tag_str:
                if is_prev_entity is True:
                    decoding_ner_sentence += ':' + prev_entity_tag+ '>'

                if token_str[0] == ' ':
                    token_str = list(token_str)
                    token_str[0] = ' <'
                    token_str = ''.join(token_str)
                    decoding_ner_sentence += token_str
                else:
                    decoding_ner_sentence += '<' + token_str
                is_prev_entity = True
                prev_entity_tag = pred_ner_tag_str[-3:] # 첫번째 예측을 기준으로 하겠음
                is_there_B_before_I = True

            elif 'I-' in pred_ner_tag_str:
                decoding_ner_sentence += token_str

                if is_there_B_before_I is True: # I가 나오기전에 B가 있어야하도록 체크
                    is_prev_entity = True
            else:
                if is_prev_entity is True:
                    decoding_ner_sentence += ':' + prev_entity_tag+ '>' + token_str
                    is_prev_entity = False
                    is_there_B_before_I = False
                else:
                    decoding_ner_sentence += token_str

        return list_of_ner_word, decoding_ner_sentence

# %%
def input_test():
    model_dir = Path('./experiments/base_model_with_crf')
    model_config = Config(json_path=model_dir / 'config.json')

    # load vocab & tokenizer
    tok_path = "./ptr_lm_model/tokenizer_78b3253a26.model"
    ptr_tokenizer = SentencepieceTokenizer(tok_path)

    with open(model_dir / "vocab.pkl", 'rb') as f:
        vocab = pickle.load(f)
    tokenizer = Tokenizer(vocab=vocab, split_fn=ptr_tokenizer, pad_fn=keras_pad_fn, maxlen=model_config.maxlen)

    # load ner_to_index.json
    with open(model_dir / "ner_to_index.json", 'rb') as f:
        ner_to_index = json.load(f)
        index_to_ner = {v: k for k, v in ner_to_index.items()}

    # model
    model = KobertCRF(config=model_config, num_classes=len(ner_to_index), vocab=vocab)

    # load
    model_dict = model.state_dict()
    checkpoint_path = '/opt/ml/ocr/ner/ner_kobert/experiments/base_model_with_crf_val/best-epoch-12-step-1000-acc-0.961.bin'
    checkpoint = torch.load(checkpoint_path, map_location=torch.device('cpu'))
    # checkpoint = torch.load("./experiments/base_model_with_crf_val/best-epoch-12-step-1000-acc-0.960.bin", map_location=torch.device('cpu'))
    convert_keys = {}
    for k, v in checkpoint['model_state_dict'].items():
        new_key_name = k.replace("module.", '')
        if new_key_name not in model_dict:
            print("{} is not int model_dict".format(new_key_name))
            continue
        convert_keys[new_key_name] = v

    model.load_state_dict(convert_keys)
    model.eval()
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    model.to(device)
    decoder_from_res = DecoderFromNamedEntitySequence(tokenizer=tokenizer, index_to_ner=index_to_ner)

    while(True):
        input_text = input('input> ')
        if input_text == 'end':
            break
        
        list_of_input_ids = tokenizer.list_of_string_to_list_of_cls_sep_token_ids([input_text])
        x_input = torch.tensor(list_of_input_ids).long().to(device)
        list_of_pred_ids = model(x_input)

        list_of_ner_word, decoding_ner_sentence = decoder_from_res(list_of_input_ids=list_of_input_ids, list_of_pred_ids=list_of_pred_ids)
        print("output>", decoding_ner_sentence)
        print("")

# %%
input_test()
# Out:
# output>  <김 나 영:PER> .
#
# output>  김 . 나 . 영.
#
# output>
#
# output>  안녕하세요, <김나영:PER>입니다.
#
# output>
#
# output>  안녕하세요, <김 나 영:PER> 입니다.
#
# output>
#
# output>  안녕하세요저는<김나영:PER>입니다반갑습니다.
#
# output>
#
# output>  반갑습니다안녕하세요저는<김나영:PER>입니다그래서<서울:LOC>시반갑습니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B49.50.162.64/opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb#ch0000003vscode-remote?line=0'>1</a> input_test()
#
# /opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb Cell 3' in input_test()
#      <a href='vscode-notebook-cell://ssh-remote%2B49.50.162.64/opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb#ch0000002vscode-remote?line=37'>38</a> decoder_from_res = DecoderFromNamedEntitySequence(tokenizer=tokenizer, index_to_ner=index_to_ner)
#      <a href='vscode-notebook-cell://ssh-remote%2B49.50.162.64/opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb#ch0000002vscode-remote?line=39'>40</a> while(True):
# ---> <a href='vscode-notebook-cell://ssh-remote%2B49.50.162.64/opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb#ch0000002vscode-remote?line=40'>41</a>     input_text = input('input> ')
#      <a href='vscode-notebook-cell://ssh-remote%2B49.50.162.64/opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb#ch0000002vscode-remote?line=41'>42</a>     if input_text == 'end':
#      <a href='vscode-notebook-cell://ssh-remote%2B49.50.162.64/opt/ml/ocr/ner/ner_kobert/Interactive_shell_NER.ipynb#ch0000002vscode-remote?line=42'>43</a>         break
#
# File /opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1070'>1071</a> if not self._allow_stdin:
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1071'>1072</a>     raise StdinNotImplementedError(
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1072'>1073</a>         "raw_input was called, but this frontend does not support input requests."
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1073'>1074</a>     )
# -> <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1074'>1075</a> return self._input_request(
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1075'>1076</a>     str(prompt),
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1076'>1077</a>     self._parent_ident["shell"],
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1077'>1078</a>     self.get_parent("shell"),
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1078'>1079</a>     password=False,
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1079'>1080</a> )
#
# File /opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1116'>1117</a>             break
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1117'>1118</a> except KeyboardInterrupt:
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1118'>1119</a>     # re-raise KeyboardInterrupt, to truncate traceback
# -> <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1119'>1120</a>     raise KeyboardInterrupt("Interrupted by user") from None
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1120'>1121</a> except Exception:
#    <a href='file:///opt/conda/envs/ocr_new/lib/python3.8/site-packages/ipykernel/kernelbase.py?line=1121'>1122</a>     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Namecard Test

# %%
json_path = '/opt/ml/ocr/info_val.json'

# %%
import json

with open(json_path, 'r') as f:
    json_data = json.load(f)

anns = json_data['annotations']

# %%
all_words_list = []

for ann in anns:
    bboxs_per_image = ann['ocr']['word']

    words_in_image = ''
    for bbox in bboxs_per_image:
        words_in_image += bbox['text'] + ' '
    words_in_image += '.'
    all_words_list.append(words_in_image)

# %%
def namecard_test():
    model_dir = Path('./experiments/base_model_with_crf')
    model_config = Config(json_path=model_dir / 'config.json')

    # load vocab & tokenizer
    tok_path = "./ptr_lm_model/tokenizer_78b3253a26.model"
    ptr_tokenizer = SentencepieceTokenizer(tok_path)

    with open(model_dir / "vocab.pkl", 'rb') as f:
        vocab = pickle.load(f)
    tokenizer = Tokenizer(vocab=vocab, split_fn=ptr_tokenizer, pad_fn=keras_pad_fn, maxlen=model_config.maxlen)

    # load ner_to_index.json
    with open(model_dir / "ner_to_index.json", 'rb') as f:
        ner_to_index = json.load(f)
        index_to_ner = {v: k for k, v in ner_to_index.items()}

    # model
    model = KobertCRF(config=model_config, num_classes=len(ner_to_index), vocab=vocab)

    # load
    model_dict = model.state_dict()
    checkpoint_path = '/opt/ml/ocr/ner/ner_kobert/experiments/base_model_with_crf_val/best-epoch-12-step-1000-acc-0.961.bin'
    checkpoint = torch.load(checkpoint_path, map_location=torch.device('cpu'))
    # checkpoint = torch.load("./experiments/base_model_with_crf_val/best-epoch-12-step-1000-acc-0.960.bin", map_location=torch.device('cpu'))
    convert_keys = {}
    for k, v in checkpoint['model_state_dict'].items():
        new_key_name = k.replace("module.", '')
        if new_key_name not in model_dict:
            print("{} is not int model_dict".format(new_key_name))
            continue
        convert_keys[new_key_name] = v

    model.load_state_dict(convert_keys)
    model.eval()
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    model.to(device)
    decoder_from_res = DecoderFromNamedEntitySequence(tokenizer=tokenizer, index_to_ner=index_to_ner)

    tag_result = {
    'PER': [],
    'LOC': [],
    'ORG': [],
    'POH': [],
    'DAT': [],
    'TIM': [],
    'DUR': [],
    'MNY': [],
    'PNT': [],
    'NOH': []
    }

    for input_text in all_words_list:
        
        list_of_input_ids = tokenizer.list_of_string_to_list_of_cls_sep_token_ids([input_text])
        x_input = torch.tensor(list_of_input_ids).long().to(device)
        list_of_pred_ids = model(x_input)

        list_of_ner_word, decoding_ner_sentence = decoder_from_res(list_of_input_ids=list_of_input_ids, list_of_pred_ids=list_of_pred_ids)
        print("output>", decoding_ner_sentence)
        print("--------------------------------------------------------------------------------------------------------")
        print("")

        for tags in decoding_ner_sentence.replace('>', '<').split('<'):
            if ':' in tags:
                word, tag = tags.split(':')[-2:]
                if tag in tag_result.keys():
                    tag_result[tag].append(word)

    return tag_result

# %% [markdown]
# ### NER Tagset
#
# - 8개의 태그
#   - PER: 사람이름
#   - LOC: 지명
#   - ORG: 기관명
#   - POH: 기타
#   - DAT: 날짜
#   - TIM: 시간
#   - DUR: 기간
#   - MNY: 통화
#   - PNT: 비율
#   - NOH: 기타 수량표현
# - 개체의 범주
#   - 개체이름: 사람이름(PER), 지명(LOC), 기관명(ORG), 기타(POH)
#   - 시간표현: 날짜(DAT), 시간(TIM), 기간 (DUR)
#   - 수량표현: 통화(MNY), 비율(PNT), 기타 수량표현(NOH)

# %%
result = namecard_test()
# Out:
# /opt/conda/envs/ocr_new/lib/python3.8/site-packages/torchcrf/__init__.py:305: UserWarning: where received a uint8 condition tensor. This behavior is deprecated and will be removed in a future version of PyTorch. Use a boolean condition instead. (Triggered internally at  /opt/conda/conda-bld/pytorch_1646755853042/work/aten/src/ATen/native/TensorCompare.cpp:333.)
#   score = torch.where(mask[i].unsqueeze(1), next_score, score)
# output>  내 비장의 무기는 아직 손안에 있다.그것은 희망이다 <제이준코스메틱:ORG> 주식회사 부품1팀 <서:PER>도가 <표용환:PER> 웹 <www.irisgoodtour.com:POH> 메일 <uo6ay83k[UNK]:POH><4nsys.com:POH> 유선 (<+55:POH>)626-55-845 핸드폰 (<+55:POH>)4379-51-4960 팩스 (<+55:POH>)2038-79-284 (06150) <서울특별시:LOC> <강남구:LOC> <테헤란로 329:LOC> (<역삼동:LOC>) 1215호 <830:NOH>-66-69259 <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <큐온컴퍼니:ORG> 가난은 많은 뿌리를 갖고 있습니다. 그러난 큰 뿌리는 무식이다. 비상기획관 <김대성:PER> 한국어강사 <Web:POH>) <www.tnyint.co.kr P:POH>hone) (<+386:POH>)<623-88-5891 Fax:POH>) (<+386)8111-2097-7085:POH> <Tel:POH>) (<+386:POH>)<004-17-828:POH> <Email:POH>) <5rtrpk[UNK]:POH><until.co.kr:POH> (3<5229:NOH>) <대전광역시:LOC> <서구:LOC> 둔지<로:POH> <36:NOH> <4층:NOH> <404호:NOH> <619:NOH>-08-86934 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <에스브이 컴퍼니:ORG> 고통에서 도피하지 말라. 고통의 밑바닥이 얼마나 감미로운 가를 맛보라. <최우석:PER> 기획조정실 PD H. <www.necktiehouse.com E. feid[UNK]ikgia.com:POH> F. <15-1488-4422:POH> M. <016-1950-271:POH> T. <6615-89-200:POH> <119-07-28945:POH> <(32543:POH>) <충청남도:LOC> <공주시:LOC> <백제문화로 2148-21:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  당신이 할 수 있는 가장 큰 모험은, 당신이 꿈꾸는 삶을 사는 것이다. <헤이수:ORG> 재경팀 <박성희:PER> 대통령 Email. <khdbnql6[UNK]:POH><epntec.com Fax:POH>. <43-816-707:POH> <Web. www.edupangpang.co.kr:POH> <M:POH>obile. <635-91-8443:POH> Tel. <5220-662-256:POH> <(06150:NOH>) <서울특별시:LOC> <강남구:LOC> <테헤란로 329 (:LOC>역<삼동:LOC>) <1215호:POH> <355-17-01054:NOH> <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  재능은 한계가 있지만 노력엔 한계가 없다. <반한달:PER> 특수효과전문가 경영지원처 <윤정원:PER> 연락처) <5112-13-8068:POH> 휴대전화) <1123-7898-9961:POH> 팩스) <688-75:POH>-465 이메일) <c1j6a[UNK]hanmail.net:POH> 웹) <mizcolor.com:POH> <(:DAT><0617:DAT>2) <서울특별시:LOC> <강남구:LOC> <봉은사로112길 22 3층:LOC>(<삼성동:LOC>) <440-75-51519:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  영양센타 눈물과 더불어 빵을 먹어 보지 않은 자는 인생의 참다운 맛을 모른다. 시의원 <ICT혁신:ORG>단 <김영도:PER> 전자우편) <i6jdlb3ig[UNK]acecode.kr:POH> 팩스) <263-3013:POH>-1<10:DAT> 전화) <938-789-0259:POH> 웹) <www.v-violin.com:POH> 무선전화) <44-8741-317 650-09-81000:POH> <(38065:POH>) <경상북도:LOC> <경주시:LOC> <외외1길:LOC> 166 <2층:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  인간은 의욕 하는 것 그리고 창조하는 것에 의해서 만이 행복하다. <불링누리:ORG> 비올리스트 <문정원:PER> 광고팀 <T : 9361-77-7612:POH> <E : 6i5i52blf[UNK]beosome.com:POH> <M : 6235-725-3255:POH> <F : 392-816-6503:POH> <H ::POH> <www.modetournara.com:POH> <914-64-52302:POH> <(07228:POH>) <서울특별시:LOC> <영등포구:LOC> <영신로 220 1408호:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <이진형:PER> 관재팀 그린코디네이터 연락처) <48-954-582:POH> 사이트) <www.snique.co.kr:POH> 팩스) <31-89-0164:POH> 휴대폰<):POH> <5272-3383-5878:POH> 이메일) <in-qrdjumwz[UNK]eyesel.com:POH> <(07665:POH>) <서울특별시:LOC> <강서구:LOC> <등촌로55길 21:LOC> <4층 691-68-87784:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  이기는 것이 중요한 것이 아니다. 어떻게 노력하는가가 문제이다. 왼손붓잡이 주변환경정리전문가 <홍경문:PER> 부품2팀 <www.datadoctor.co.kr:POH> (<+685)82-45-9232:POH> (<+685)210-548-1450:POH> (<+685)669-35-343:POH> <0plrl1[UNK]:POH><paran.co.kr:POH> <843-84-16123 (0621:POH>2) <서울특별시:LOC> <강남구:LOC> <테헤란로 328:LOC> <동우빌딩 10층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  희망을 품지 않은 자는 절망도 할 수 없다. <마계:POH>서플리 <정규진:PER> <샵마스터 빅데이터부:POH> <Email 37wuwfv2:POH>[UNK]<mymoins.net Fax 9230:POH>.8687.6821 <Site uiseokshop.nt.co.kr:POH> <Tel:POH> <652.6297.609:NOH> <Phone:POH> <17.43.8404 (06212):NOH> <서울특별시:LOC> <강남구:LOC> <선릉로 427:LOC> <13층:NOH> <578-23-58941:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  열매를 맺지 않는 꽃은 심지 말고 의리 없는 친구는 사귀지 말라. 주식회사 <새론디자인:ORG> <샵마:ORG>스터 <이선유:PER> 비상기획관 핸드폰. <8451-168-7039:POH> 홈페이지. <www.beautygem.co.kr:POH> 전자우편. <fa8f7dhw[UNK]:POH><mskshop.net:POH> 전화. <3564-482-636:POH> 팩스. <129-39-7939:POH> <(07236:POH>) <서울특별시:LOC> <영등포구:LOC> <의사당대로 8 태:LOC>흥빌딩 <602호:POH> <769-56-81429:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  재능은 한계가 있지만 노력엔 한계가 없다. <혜[UNK]틀연구소:ORG> 주식회사 채권팀 <김한수:PER> 슈트 액터 메일 <bo4ra6xie[UNK]blan.co.kr:POH> 팩스 <619-96-3364:POH> <휴대전화:POH> <423-844-849:POH> 연락처 <1015-37-727:POH> 사이트 <mvfunding.com:POH> <853-73-78209:POH> <(06180:POH>) <서울특별:LOC>시 <강남구:LOC> <테헤란로 518 4층:LOC> (<대치동:LOC>) .
# --------------------------------------------------------------------------------------------------------
#
# output>  럽독캣 우선순위를 세밀하게 정할수록 긴급한 일이 줄어든다. 대신 시설보수팀 <이수경:PER> <Email:ORG>) <hhjo17gb0[UNK]:POH><iwix.co.kr:POH> Site) <yandb0009:POH>.com Phone) <83-248-040:POH> Tel) <56-856-9662:POH> <Fax:POH>) <6724-588-6409:POH> <087-63-38529:POH> <(03708:POH>) <서울특별시:LOC> <서대문구:LOC> <연희로 83:LOC> <은혜빌딩:LOC> 3층 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <수린산업:ORG> 오늘 달걀 <한 개:NOH> 갖는 것보다, 내인 암[UNK]을 <한 마리:NOH> 갖는 편이 낫다. 개발센터 시장 <김준규:PER> M <4910-3339-856:POH> <E f5d4dtednd[UNK]gbros.co.kr H www.lovelyherb.com:POH> <T 636-060-875:POH> <F:POH> <7587-5732-220:POH> <(05854:POH>) <서울특별시:LOC> <송파구:LOC> <법원로 128 A동 408호 861-38-30081:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <그로스 앤 홀:PER> 말을 많이 하는 것과 말을 잘하는 것은 다르다. <김현일:PER> 기획조정실 손해사정인 <Tel 8329-02-2789:POH> <Email 4l6rg3k[UNK]onstn.com Site www.dklux.kr:POH> <Fax 1890-959-169:POH> <Phone 3053-18-440 416-86-76324 (0585:POH>2) <서울특별시:LOC> <송파구:LOC> <위례광장로 120:LOC> (<장지동:LOC>, <위례중앙푸르지오1단지:LOC>) .
# --------------------------------------------------------------------------------------------------------
#
# output>  사랑은 자기 분신을 만드는 것이다. 자기 자신을 대하듯이 사랑을 베풀어야 한다. <에지리:ORG> 개발센터 <김은진:PER> 치어리더 (+1 767)<39-590-036:POH> (+1 767)326-884-3<11:DAT> <qzv[UNK]epntec.com:POH> (+1 767)373-5015-4647 <bimbim.co.kr:POH> (0<5854:NOH>) <서울특별시:LOC> <송파구:LOC> <법원로 128 A동 408호 690-96:LOC>-46041 .
# --------------------------------------------------------------------------------------------------------
#
# output>  <크린마스터:PER> 주먹을 꼭 쥔 손과는 악수를 할 수 없다. CE 연구원 <김상균:PER> M) (<+509:POH>)77-55-376 H) <www.ellicci.co.kr F:POH>) (<+509)6410-30-7723:POH> T) (<+509)359-777-9799:POH> E) <1kirby[UNK]crinity.com:POH> <567-32-09035:POH> <(41256:POH>) <대구광역시:LOC> <동구:LOC> <동대구로 503:LOC> <신천동:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <신한국인쇄소:ORG> 지도자란 희망을 파는 상인이다. <홍승정:PER> 비상기획관 통관대리인 <Site www.rainbowbigsmphone.kr Mobile:POH> <38-35-1331:POH> <Email ph0vyodaxj[UNK]gmai.com:POH> <Fax 430-1563-027:POH> <Tel 10-8830-9737:POH> <185-68-67099:NOH> <(06187:POH>) <서울특별시:LOC> <강남구:LOC> <역삼로 552 KM빌딩 5:LOC>층 <이롬플러스:LOC> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  모르는 것보다는 사실과 다르게 아는 것이 더 문제다. <스타일로직 재료연구소:ORG> <최은아:PER> 비행기 기장 <9985-5893-597:POH> <t2ygo-66z[UNK]2424.com 2523-2327-180 136-60-722:POH> <www.oh-honey.co.kr:POH> <490-79-55169:POH> <(06025:POH>) <서울특별:LOC>시 <강남구:LOC> <논현로158길 6-1:LOC> <지하1:NOH>,<지상1:NOH>,<지:NOH>상<3층:NOH>(<신사동:LOC>, <아크빌딩:LOC>) .
# --------------------------------------------------------------------------------------------------------
#
# output>  <법무사:ORG> 전략기획실 <오경수:PER> 무선) <14.41:NOH>0.7<896:NOH> 사이트) <www.atable.kr:POH> 전화) <92.5:NOH>0.6<936:NOH> 메일) <vhx4v8[UNK]google.com:POH> 팩스) <4336:POH>.7076.041 <891-16-14711:POH> (<0621:DAT>2) <서울특별시:LOC> <강남구:LOC> <테헤란로 328:LOC> <3층:NOH>(<역삼동:LOC>, <동우빌딩:LOC>) .
# --------------------------------------------------------------------------------------------------------
#
# output>  <네일마트:ORG> 몸가짐은 각자가 자기의 모습을 비추는 거울이다. 전략기획실 <김인성:PER> 검색광고마케터 <Site www.thecodi.com Tel 134-794-705 Phone 37-401-2809:ORG> <Fax 496-094-3033:POH> <Email t8h_80cxxz2[UNK]:POH><preegia.com:POH> <(41256:POH>) <대구광역시:LOC> <동구:LOC> <동대구로 503:LOC> <신천동 734-85-50480:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  프로젝트팀 <이정림:PER> PPL마케터 P) <782-964-055:POH> E) <4mg2n1[UNK]hanujie.com H:POH>) <www.n-am.co.kr T:POH>) <4358-04-619:POH> F) <380-5709-8555:POH> <(05804:POH>) <서울특별시:LOC> <송파구:LOC> <동남로 122 743-85-65873:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  회복의 유일한 길은 다시 시작하는 것이다. 필드 해양경찰 <김규한:PER> <빅데이터:ORG>부 웹) <www.uneeditem.com:POH> 연락처) <975-48-9840:POH> 팩스) <19:POH>-363-4933 메일) <ew-tfljwqi[UNK]artrank.net:POH> 유선) <3545-42-357:POH> <(38891:POH>) <경상북도:LOC> <영천시:LOC> <금완로 47:LOC> 2층 <910-23-24666:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <엣지컴퍼니:ORG> 교육의 최고의 성과는 관용이다. 프로젝션매핑디자이너 관재팀 <최광희:PER> 연락처 : <5149-5240:POH>-414 팩스 : <53-7624:POH>-714 <웹 ::POH> <jubin.co.kr:POH> 유선전화 : <592-0963-240:POH> 전자우편 : <w441f[UNK]:POH><okkot.com:POH> <(08507:POH>) <서울특별시:LOC> <금천구:LOC> <가산디지털1로 128:LOC>, <에스티엑스브이타워:LOC> <20층:NOH> <1호 478-78:NOH>-30336 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  인간이란 미소와 눈물 사이를 왕래하는 시계추와 같은 것이다. 해외구매대행연구소 <노동협력부:ORG> <오순자:PER> 무녀 3405-603-069 1018-8458-3074 <7539-282-9341:POH> <swdwb3yz[UNK]amoga.co.kr:POH> <www.imgmonster.com 186-70-24726:POH> <(13590:POH>) <경기도:LOC> <성남시:LOC> <분당구:LOC> <황새울로335번길 5:LOC> <7층:NOH>, <8층:NOH> <801호:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  내가 성공한 것은, 어느 때이건 <15분:DUR>전에 도착한 덕택이다. <시아와:ORG>세콕 한국어강사 <강정수:PER> 전산실 <Email ::POH> _xqvpzna_<nz8:POH>[UNK]<empas.com:POH> Mobile : (<+97:POH>1)115-8989-702 <Fax:POH> : (<+971)61-436-5176:POH> <Site ::POH> <www.ice25.co.kr:POH> <Tel ::POH> (<+971)928-8063-5242 584-57-748:POH>14 <:POH>(50839) <경상남:POH>도 <김:POH><해시:POH> <활천로166번길:POH> <14:POH> <2층:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <그레이스펫:POH> 요구받기 전에 충고하지 말라. <이지윤:PER> <로봇공연기획자 채권:ORG>팀 이메일. <tqd667qw8r6m[UNK]emfo.co.kr:POH> 홈페이지. <www.catsndogslove.com:POH> 팩스. <12-8609-7810:POH> 무선전화. <809-5681-244:POH> 연락처. <1789-8254-458 (06627:POH>) <서울특별시:LOC> <서초구:LOC> <강남대로 327:LOC> <6층:NOH>(<서초동:LOC>, <대륭서초타워:LOC>) <4:NOH>96-65-48933 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  최고에 도달하려면 최저에서 시작하라. 주식회사 <다인커머스 노동협력부:ORG> 기후변화전문가 <양서원:PER> 팩스 : <333-2840-3597:POH> 메일 : <206[UNK]applesc.com:POH> 휴대폰 : <49-6698-923:POH> 홈페이지 : <www.cieltech.co.kr:POH> 연락처 : <26-760-9358:POH> <633-54-13076 (0399:POH>1) <서울특별시:LOC> <마포구:LOC> <월드컵북로 40:LOC> <스페이스원빌딩 3층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <:ORG><엑스라이프:ORG> 기다림만으로 사는 사람은 굶어서 죽는다. 손해사정사 <정혜진:PER> 관재팀 <F:POH>ax : <6078-83-539:POH> Phone : <2598-19-952:POH> <Email : 6dhu12n76m[UNK]visarim.com:POH> <Web : www.osunghold.com Tel ::POH> <5437-1393-939:POH> <033-99-22162 (0614:POH>1) <서울특별시:LOC> <강남구:LOC> <테헤란로 203:LOC> <4층:NOH>, <5층:NOH>(역<삼동:LOC>, <서울인터내셔널타워:LOC>) <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <김준석:PER> 교장 인사부 웹 : <www.royalbreeder.com:POH> 팩스 : <654-25-484:POH> 유선전화 : <6794-67-2133:POH> 이메일 : <dwigysh[UNK]gmial.com:POH> 무선전화 : <05-435-572:POH> <958-97-01619:POH> <(06159:POH>) <서울특별시:LOC> <강남구:LOC> <테헤란로 423 5층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  인간이란 미소와 눈물 사이를 왕래하는 시계추와 같은 것이다. <블링코:PER> <김도전:PER> 빅데이터부 총무 <2793-17:NOH>-455 <s5kxvma1[UNK]hantool.com:POH> <58-819-866:POH> <www.woshne.co.kr 354-90-616:POH> <455-46-62467:POH> <(38891:POH>) <경상북도:LOC> <영천시:LOC> <금완로 47:LOC> <2층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  좋은 성과를 얻으려면 한 걸음 한 걸음이 힘차고 충실하지 않으면 안 된다. <인투750:POH> 게임기획자 <이누리:PER> 전략기획실 (<+960:POH>)75-72-0059 (<+960)85-0916-4099:POH> (<+960:POH>)<2285-7821-1255:POH> <b84sn[UNK]ative.kr:POH> <www.:POH><nixonstore.com (06800:POH>) <서울특별시:LOC> <서초구:LOC> <헌릉로 176 601호 577-74-89496:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <에스 커:ORG>머스 위대함에는 신비성이 필요하다. 너무 알면 사람들은 존경하지 않는다. 조리사 <유재원:PER> 인사부 F (+<1 809:NOH>)<30:DAT>.14.740 <E f2e6:POH>[UNK]<rim-inc.kr:POH> M (+1 809)<3306:NOH>.577.7018 T (+1 809)782.6500.474 <H www.efshop.co.kr:POH> (06193) <서울특별시:LOC> <강남구:LOC> <테헤란로70길 12:LOC> <3층:NOH>, <8층 801호:NOH> (대치동, <H타워:POH>) <256-70:NOH>-22814 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <트리니티 인터내셔널:ORG> 신은 용기있는자를 결코 버리지 않는다. 디지털 장의사 대리점지원팀 <김재남:PER> E. <nhzbhxve4-4c[UNK]gimail.com:POH> T. <742-637-908:POH> M. <43-5116-6218:POH> H. <www.blottopumpkin.co.kr:POH> F. <9712-75-7386:POH> <(07297:POH>) <서울특별시:LOC> <영등포구:LOC> <당산로 34:LOC> <2층:NOH> <204:NOH>~<212호:NOH> <561-85-46444:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  주식회사 <코스비즈:ORG> 고개 숙이지 마십시오. 세상을 똑바로 정면으로 바라보십시오. 재경팀 <김정연:PER> 만화가 <T : 8500-4646-1456:POH> <H : no1boho.or.kr:POH> P <::POH> <00-29-983:POH> <E : vuvoclp[UNK]qvex.co.kr:POH> <F : 73-914-402 (0624:POH>1) <서울특별시:LOC> <강남구:LOC> <강남대로 358 9층 799-53-39686:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  내가 성공한 것은, 어느 때이건 <15분:DUR>전에 도착한 덕택이다. <한국글로벌:ORG> <최은정:PER> 문화본부 공항검역관 F) <9813-12-967:POH> H) <lux4u.co.kr E:POH>) <y8gmvx117q[UNK]bgf.co.kr P:POH>) <502-1408-225:DUR> T) <6619-09-628 783-49-26849:POH> <(06194:POH>) <서울특별시:LOC> <강남구:LOC> <테헤란로70길 13:LOC> <보성빌딩 2층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  육류가공원 <이시아:ORG> 전산팀 전화 : <6372-76-516:POH> 이메일 : <t686zkph0ag[UNK]artdent.kr:POH> 사이트 : <www.버스관광.kr:POH> 무선 : <2470-8304-4340:POH> 팩스 : <3200-9974-969 320-33-46925:POH> <(06050:POH>) <서울특별시:LOC> <강남구:LOC> <언주로 725:LOC> 동관 2층 .
# --------------------------------------------------------------------------------------------------------
#
# output>  가난은 많은 뿌리를 갖고 있습니다. 그러난 큰 뿌리는 무식이다. <네오원:ORG> <임동근:PER> 성과관리처 빅데이터분석가 연락처. (<+353:POH>)1776-21-874 무선전화. (<+353)53-738-0509:POH> 팩스. (<+353)15-4453-1287:POH> 웹. <www.spopeli.co.kr:POH> 전자우편. <cqt[UNK]:POH><cl.ne.kr:POH> <666-22-62888:POH> <(06125:POH>) <서울:LOC>특별시 <강남구:POH> <논현:POH><로:POH> <563:POH> 언<주타워:POH> <3층:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  실행 불가능한 일이 실행 가능한 일을 방해하도록 하지 말라. <삼미산업:ORG> <이용후:PER> 쇼호스트 전략기획실 (<+670:POH>)391-241-5740 (<+670)35-1830-504:POH> <www.unseworld.co.kr:POH> (<+670)9198-07-6521:POH> <1jzam[UNK]ative.kr:POH> (1<0846:DAT>) <경기도:LOC> <파주시:LOC> <탄현면:LOC> <축현산단로 56-16:LOC> (<축현리:LOC>) <011-03-31109:POH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  듀듀 수가 많다고 반드시 강한 것은 아니다. 지방자치단체장 사업추진단 <서:PER>용설 연락처 : <5680.561.5450:NOH> 팩스 : <19.4411.6691:NOH> 유선 : <81.77.8478:NOH> 전자우편 : <ii7dkh[UNK]2biztem.com:POH> 홈페이지 : <www.kimsdressroom.com:POH> <449-32-33890:POH> <(16573:POH>) <경기도:LOC> <수원시:LOC> <팔달구:LOC> <효원로 116:LOC> <신나라빌딩 1층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <여명:NOH>기업 불가능한 일이 존재하는 것이 아니라 불가능하다는 생각이 존재하는 것이다. 재경팀 수학자 <김기환:PER> 사이트. <ipink.co.kr:POH> 메일. <2gejfr[UNK]daesang.com:POH> 팩스. <689-323-4068:POH> 핸드폰. <433-84-5580:POH> 연락처. <77-276-3756:POH> <(06149:POH>) <서울특별시:LOC> <강남구:LOC> <선릉로 541 679-29-41670:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <김지숙:PER> SNS마케터 프로젝트팀 T. <800-63-960:POH> P. <129-1078-849:POH> E. <zlkpfgaum2[UNK]hananet.net H. cskim59.cafe24.com:POH> F. <18-0429-994:POH> <(34179:POH>) <대전광역시:LOC> <유성구:LOC> <도안대로 591:LOC> <5층:NOH> <504호:NOH> (<봉명동:LOC>, <명동프라자:LOC>) <202-88-79543:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  검시관 IT 1팀 <윤솔비:PER> Mobile) (+84)6299-68-443 <F:POH>ax) (+84)002-892-056 <Email:POH>) <1:POH>t6[UNK]<mimobio.com:POH> Tel) (+<84:POH>)5182-3906-4742 <Web:POH>) <pastelsoap.com:POH> <807-70-70253:POH> <(14548:POH>) <경기도:LOC> <부천시:LOC> <중동로248번길 71 901호:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  수가 많다고 반드시 강한 것은 아니다. 쌍팔삼 상생정책관 <안상현:PER> 국장 <Web:POH>. <www.codiyou.com:POH> Fax. (+960)3250-71-2895 Phone. (+960)<0409-12-2138:POH> <Email:POH>. <-e8[UNK]kmug.co.kr:POH> Tel. (<+960:POH>)72-5884-7814 <(07228:POH>) <서울특별시:LOC> <영등포구:LOC> <영신로 220:LOC> <1408호 658-96-27123:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  안경OK콘텍트 인생에 뜻을 세우는데 있어 늦은 때라곤 없다 <김정호:PER> <아:ORG>바타디자이너 청장실 Mobile 95-6590-215 <Tel 973-36-126:POH> <Site www.manposystem.com:POH> <Fax 276-6671-924:POH> <Email 1js_hlnat[UNK]kmug.co.kr:POH> (1<0846:NOH>) <경기도:LOC> <파주시:LOC> <탄현면:LOC> <축현산단로 56-16:LOC> (<축현리:LOC>) 569-21-64060 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <도리도리클럽:ORG> 아는 것을 안다하고, 모르는 것을 모른다하는 것이 말의 근본이다. <e-Business팀:ORG> <송영숙:PER> 음악치료사 유선전화 473-838-717 팩스 808-82-9652 사이트 <www.carinside.com:POH> 휴대폰 <055-084-926:POH> 전자우편 <7wg004rnhe[UNK]nave.rcom:POH> <(07228:POH>) <서울특별시:LOC> <영등포구:LOC> <영신로 220:LOC> <1408호:NOH> <821-39-53:NOH>733 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <이혜원:PER> 전산실 음양사 메일. <nyhy[UNK]minamsa.com:POH> 팩스. <31-276-9538:POH> 연락처. <438-2871-063:POH> 핸드폰. <221-881-447:POH> 사이트. <www.luxuryseven.co.kr:POH> <613-72-75397:POH> <(06149:POH>) <서울특별시:LOC> <강남구:LOC> <테헤란로53길 22:LOC> <2층:NOH>, <3층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  총무팀 <오정근:PER> 아트딜러 Fax : <401-5462-910:NOH> Tel : 817-830-4570 <Email : 0x1-[UNK]kr.naos.com Site ::POH> <www.hwalimwon.com Mobile:POH> : <73-08-850 609-78-71251:POH> <(06178:POH>) <서울특별시:LOC> <강남구:LOC> <삼성로86길 7:LOC>, <삼성빌딩 5층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  행운은 마음의 준비가 있는 사람에게만 미소를 짓는다. <쇼핑DS:ORG> <김승옥:PER> 미디어홍보실 오페라 배우 유선 <0241-037-645:POH> 사이트 <www.from-zany.com:POH> 휴대폰 <93-5226-7414:POH> 팩스 <8187-828-9181:POH> 전자우편 <1ymuvn36l[UNK]scinco.com:POH> <249-31-65034:POH> <(47505:POH>) <부산광역시:LOC> <연제구:LOC> <중앙대로 1231:LOC> <에이스제이엠빌딩:LOC> <8층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  가난은 많은 뿌리를 갖고 있습니다. 그러난 큰 뿌리는 무식이다. <공구이마트:ORG> <서영진:PER> 전지개발센터 학교보안관 <3v:POH>--0[UNK]<apian.co.kr:POH> (+213)129.231.436 (<+213:POH>)<609:POH>.0649.549 (+213)<58:NOH>.242.5<86:DAT> <www.risehomme.com:POH> <094-81-87635:POH> <(05556:POH>) <서울특별시:LOC> <송파구:LOC> <올림픽로 76 제이타워 14층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  플라워큐 세상은 고통으로 가득하지만 한편 그것을 이겨내는 일로도 가득하다. <노동협력부:ORG> <이현경:PER> 부사관 E) <ridhl[UNK]4dim.co.kr H:POH>) <www.esuper.ehxundai.com T:POH>) <7432:POH>-3<27-114:DUR> F) <2247-316-9210:POH> M) <3583-949-878:POH> <987-97-26679:POH> (04300) <서울특별시:LOC> <용산구:LOC> <청파로 383:LOC> 1층 .
# --------------------------------------------------------------------------------------------------------
#
# output>  빅마인드 산다는것 그것은 치열한 전투이다. 민간조사관 <박덕희:PER> <CSR:ORG>팀 Tel : (+1 670)<0233-805:POH>-360 Phone : (+1 670)225-65-670 <Email : 2au3thnmulrf[UNK]dece.co.kr:POH> <Web ::POH> <www.fine-navi.co.kr:POH> <Fax:POH> : (+1 670)<1638-8143-093:POH> (07287) <서울:LOC>특별시 <영등포구:LOC> <경인로77길:LOC> <49 109동 201:POH>-185 376-86-64143 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <라온5:POH> 위험을 알면 위험이 사라진다. <e-Business팀:ORG> <안진우:PER> <맥주마이스터:ORG> E) <q6u575pgs[UNK]94.com F:POH>) <633-65-919:POH> T) <:NOH>52-238-801 P) <236-37-4244:POH> H) <martiniromance.com:POH> (0<7665:POH>) <서울특별시:LOC> <강서구:LOC> <등촌로55길 21:LOC> <4층:NOH> <172-90-45097:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  위대한 사람들은 목적을, 소인들은 공상을 가지고 있다. 가온해 DS 쇼핑호스트 <이준식:PER> 연락처 : <617-0793-4792:POH> 전자우편 : <0bofj[UNK]nave.rcom:POH> 연락처 : <75-4723-5333:POH> 팩스 : <97-1893-2919:POH> 홈페이지 : <www.saladmiin.com:POH> <(06099:POH>) <서울특별시:LOC> <강남구:LOC> <학동로 326 139-52-96120:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  행복한 결혼이란 죽을 때까지 따분하지 않은 대화의 연속을 말하는 것이다. <일성:ORG>유통 수습 비상기획관 <김경애:PER> 무선전화) <7561:NOH>.<24:DAT>.<9029:DAT> 웹) <tuberose.co.kr:POH> 전화) <989:NOH>.840.6<5:NOH>69 팩스) <303:NOH>.3625.<62:DAT>67 메일) <ttgx-[UNK]elwox.com:POH> (4<1256:DAT>) <대구광역시:LOC> <동구:LOC> <동대구로 503:LOC> <신천동 699-49-88609:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  현명한자는 적으로부터 많은 것을 배운다. <본디컴퍼니:ORG> 초등학교교사 <서강석:PER> <e-Business:ORG>팀 연락처 (<+970:POH>)<10-55-532:POH> 휴대폰 (<+:POH>970)<00-242:POH>-8123 <메일 06a8-1h[UNK]gmail.net:POH> 팩스 (<+970)3099-079-247:POH> 홈페이지 <www.080-067-3355.co.kr:POH> <429-61-87351 (0621:POH>2) <서울특별시:LOC> <강남구:LOC> <선릉로 427 13층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  부끄러움을 모르는 것은 부끄러운 일이다. <YQ신라:ORG> <임경순 재료연구소:PER> 동물매개심리사 Tel) (+62)7164-667-5685 Fax) (+62)4637-39-603 <M:POH>obile) (<+62:POH>)492-2504-3<02:DAT> <Email:POH>) <obi[UNK]artdent.kr Site:POH>) <www.happyjumbbang.com:POH> <994-74-24519:POH> (08511) <서울특별시:LOC> 금<천:POH><구:POH> <:POH>[UNK]<꽃:POH><로:POH> <278:POH> <905호:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  윤 세상은 고통으로 가득하지만 그것을 극복하는 사람들로도 가득하다 <임병우:PER> 시설보수팀 학습매니저 팩스. (<+230:POH>)<084-94-0631:POH> 사이트. <www.cocotan.co.kr:POH> 무선. (<+230)58-4764-866:POH> 유선전화. <(:POH><+230)99-3483-7482:POH> 전자우편. <rm_ndz[UNK]:POH><floppy.kr:POH> <282-40-78607:POH> <(04789:POH>) <서울특별시:LOC> <성동:LOC>구 <아:POH><차산로:POH> <17:POH> <서울:LOC><숲:POH><L타워:POH> <12:POH><03호:DAT> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  주식회사 <한국유시티연구소:ORG> 죄는 미워하고 죄수는 사랑하라. 동물원큐레이터 DS <유봉진:PER> 메일) <:POH>et_7krajb[UNK]mazars.kr 홈페이지) <www.sting925.com:POH> 핸드폰) (<+265)39-992-120:POH> 전화) (<+265)260-258-4018:POH> 팩스) (<+265:POH>)2587-260-6476 <411-59-62677:POH> <(54666:POH>) <전라북도:LOC> <익산시:LOC> <오산면:LOC> <무왕:LOC>로2<길:LOC> <262:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  부끄러움을 모르는 것은 부끄러운 일이다. <수미트앤푸드:ORG> <녹색건축물인증심사원:ORG> <배영대:PER> 비상기획관 Site : <www.10일다이어트.com Email : ah3eygk[UNK]:POH><abko.co.kr Mobile:POH> : 428-06-4353 <Fax:POH> : <00-479-782 Tel : 568-7072-048:POH> <111-39-05838:NOH> (06211) <서울특별시:LOC> <강남구:LOC> <테헤란로 322 서:LOC>관 <19층:NOH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <베리타스:ORG>기획 다른 사람의 좋은 습관을 내 습관으로 만든다. <강태홍:PER> 화물차 기사 상생정책관 E. <32rgk6[UNK]impbio.com:POH> P. 3024-7799-469 H. <www.puscompany.co.kr:POH> F. <388-3968-4746:POH> T. <447-2315-340:POH> <(06194:POH>) <서울특별시:LOC> <강남구:LOC> <삼성로85길 28:LOC> <우진빌딩 336-11-75140:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  기억을 증진시키는 가장 좋은 약은 감탄하는 것이다. <인더브라운 CSR팀:ORG> 전자기사 <권기은:PER> 사이트) <snaphers.com:POH> 이메일) <zdk17qkf[UNK]sassi.co.kr:POH> 팩스) <7148-0959-2808:POH> 핸드폰) <649-5784-8820:POH> 연락처) <42-2499-4377:POH> <(13590:POH>) <경기도:LOC> <성남시:LOC> <분당구:LOC> <황새울로335번길 5:LOC> <7층:NOH>, <8층:NOH> <801호:NOH> <856-82-:NOH>65900 <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  나노메모리 먼저핀꽃은 먼저진다 남보다 먼저 공을 세우려고 조급히 서둘것이 아니다 <정강우:PER> CSR팀 키보디스트 팩스) (+1 671)<02-586-096:POH> 이메일) <uml:POH>l_<[UNK]633lab.com:POH> 웹) <www.makerjoa.com:POH> 무선전화) (<+1 671:POH>)7766-7794-0009 연락처) (+1 671)<3455-89-7224:POH> (06159) <서울특별시:LOC> <강남구:LOC> <테:LOC>헤란<로:POH> <423:NOH> <5층:NOH> <327-04-9:NOH><3689:NOH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  아장아장 단순하게 살라. 쓸데없는 절차와 일 때문에 얼마나 복잡한 삶을 살아가는가? 이미징사업팀 <김태훈:PER> 재활승마치료사 Site. <www.hanwoocall.co.kr:POH> Tel. <1836-63-9747:POH> <Email:POH>. <jw52sc[UNK]atfipet.com Phone:POH>. <473-69-1506:NOH> <F:POH>ax. <50-22-4749:POH> <(10846:POH>) <경기도:LOC> <파주시:LOC> <탄현면:LOC> <검산로 484:LOC> 가동 <2층:NOH> 678-54-53316 <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  오랫동안 꿈을 그리는 사람은 마침내 그 꿈을 닮아간다. 무무 호스트 <손신자:PER> 프로젝트팀 E) <svh_0w:POH>[UNK]<afseoul.com F:POH>) <8620.58.0947:DUR> M) <38.938:NOH>.735 H) <www.fiston.co.kr:POH> T) <837:NOH>.2629.575 (06150) <서울특별시:LOC> <강남구:LOC> <테헤란로 327 604:LOC>, <605호 273-69-26177:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <디컴파운드:ORG> 오늘을 붙들어라! 되도록 내일에 의지하지 말라! 펀드애널리스트 미디어홍보실 <홍승정:PER> 전자우편. <abs[UNK]amoga.co.kr:POH> 전화. <23-590-1747:POH> 무선전화. <272-0563-672:POH> 홈페이지. <www.wehace.com:POH> 팩스. <737-98-6584:POH> <(06227:POH>) <서울특별시:LOC> <강남구:LOC> <논현로72길 7 647-51-40210:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  바닷물이 마르면 나중에 밑이 보인다. 그러나 사람은 죽어도 그 마음을 알지 못한다. <한진LED:ORG> <권순재:PER> 배구선수 <노동협력부:ORG> 팩스 : <30-8020-5188:POH> 무선전화 <::POH> <547-046-853:POH> 연락처 : <452-1449-602:POH> 전자우편 : <6s5m7rh3[UNK]:POH><gonggan.com:POH> 웹 : <wisemusic.co.kr:POH> (06043) <서울특별시:LOC> <강남구:LOC> <강남대로140길 18:LOC> <4층 393-84-9:NOH>2840 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  눈물과 더불어 빵을 먹어 보지 않은 자는 인생의 참다운 맛을 모른다. <엠아이비 와이 전자:ORG>팀 대신 <최우석:PER> F. <4234:NOH>.1968.466 T. <78:DUR>.390.5024 M. <984:NOH>.8662.5108 <H.:POH> <www.yisuh.com:POH> <E. qkbxln52:POH>x[UNK]pakovy.net (41166) <대구광역시:LOC> <동구:LOC> <화랑로 471:LOC> (<용계동:LOC>) <374-26-39836:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <함소인:PER> 개인자산관리사 미디어홍보실 유선전화 <18-820-632:POH> 메일 <c_-ocn2a8[UNK]hamac.co.kr:POH> 무선전화 <95-909-2425:POH> 팩스 <632-01-6096:POH> 웹 <ns525.com:POH> <284-68-39664:POH> <(06187:POH>) <서울특별시:LOC> <강남구:LOC> <역삼로 552 KM빌딩 5층:LOC> <이롬플러스:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  진실을 말할 때는 그것을 숨길 때만큼이나 주의를 기울어야 한다. <썸앤룩 경마조교사 개발센터:ORG> <김찬호:PER> 이메일 : <8xu8xk_o[UNK]1px.kr:POH> 연락처 : <1658-4917:POH>-2207 웹 : <www.onkukmin.co.kr:POH> 연락처 : <4018-964-500:POH> 팩스 : <651-1:POH><02-361 432-90-22052:POH> <(06103:POH>) <서울특별시:LOC> <강남구:LOC> <선릉로 615:LOC> (<논현동:LOC>, <썬라이더빌딩:LOC>) .
# --------------------------------------------------------------------------------------------------------
#
# output>  아는 것을 안다하고, 모르는 것을 모른다하는 것이 말의 근본이다. <커피앤디:ORG> 정시훈련전문가 <최경민:PER> 성과관리처 Mobile. <86-23-783:POH> <Ema:POH>il. <x87t8u[UNK]:POH><sassi.co.kr:POH> <Web. www.disneysarang.com Fax:POH>. <61-048-027:POH> Tel. <59-7108-596:POH> <094-77-23517:POH> <(05556:POH>) <서울특별시:LOC> <송파구:LOC> <올림픽로:LOC> 76 <제:POH>이타워 <14층:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  채 고생하는 사람들 때문에 세계는 발전하고 있다. <여명수:PER> 준사관 노사협력팀 전자우편) <agldkys7r[UNK]waver.com:POH> 휴대폰) <0761-499:POH>-456 팩스) <535-7062-2720:POH> 유선) <04-61-0632:POH> 사이트) <www.haokershop.co.kr:POH> (06194) <서울특별시:LOC> <강남구:LOC> <삼성로85길 28:LOC> <우진빌딩 157-27-41654:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  주식회사 <201호:NOH> 인생의 고뇌를 맛본 자일수록 생명의 존귀함을 느낀다. <김예림:PER> 전산팀 비올리스트 무선 : <34-8486-5043:POH> 팩스 : <658-74-1543:POH> 메일 : <wgg1scxyoa[UNK]netian.com:POH> 홈페이지 : <www.akbonara.co.kr:POH> 연락처 : <45-6490-2904:POH> <(06173:POH>) <서울특별시:LOC> <강남구:LOC> <영동대로96길 20:LOC> <3층:NOH>(<삼성동:LOC>) <879-51-678:POH>29 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  비상기획관 <위선균:PER> 음식메뉴개발자 <P 99-96-278 E tviis[UNK]yahoo.co.kr H amassmall.com T 8626-72-972:POH> <F 18-2732-522:POH> <426-05-68985 (4214:POH>2) <대구광역시:LOC> <수성구:LOC> <들안로 236:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <문화본부:ORG> <서훈:PER> 리포터 사이트. <www.saboa.co.kr:POH> 연락처. <7360-48-343:POH> 팩스. <86-76-2062:POH> 연락처. <0464-497-3237:POH> 이메일. <c7eh-[UNK]2424.com:POH> (<0618:DAT>1) <서울특별시:LOC> <강남구:LOC> <테헤란로 520:LOC> <8층:NOH>, <15층:NOH> <016-33-34301:POH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  상상력은 우리가 날릴 수 있는 가장 높은 연이다. <:ORG>[UNK]버거 선박정비원 시설보수팀 <김기태:PER> Mobile. <967.747.9579:NOH> <Email:POH>. --s2s0z<[UNK]sohu.com Fax:POH>. <6296.953.614:NOH> Tel. <32.7647.463:NOH> <Web:POH>. <www.gagong.com:POH> <(06103:NOH>) <서울특별시:LOC> <강남구:LOC> <선릉로 615:LOC> (<논현동:LOC>, <썬라이더빌딩:LOC>) <761-:LOC>33-97223 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  오렌지쇼핑 문제는 목적지에 얼마나 빨리 가느내가 아니라 그 목적지가 어디냐는 것이다. <김지수:PER> 청장실 법조인 <www.khsoo.co.kr:POH> <51:NOH>.91.0877 <489:NOH>.7291.635 <gce7vhzo[UNK]hr.re.kr:POH> <12.0:NOH><39:NOH>.080 <690:NOH>-20-23543 (35203) <대전광역시:LOC> <서구:LOC> <둔산대로117번길 95 D:LOC>동 <6층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  빈둥대는 것과 공허하게 있는 것보다 유해한 것은 없다. <원광세이프티:ORG> 지원팀 <박정호:PER> <카지노:ORG> H) <www.unilangs.kr E:POH>) <u552-tfld[UNK]bisket.art F:POH>) <2527-25-039:POH> P) <1611-348-9823:POH> T) <68-8022-968:POH> <193-16-95197 (0621:POH>2) <서울특별시:LOC> <강남구:LOC> <선릉로 427:LOC> <13층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <김민규:PER> 테마파크 사업단 손해사정인 H) <www.openbird.com F:POH>) <98-81-818:POH> E) <jskpr[UNK]benedly.com T:POH>) <152-52-0918:POH> M) <9242-1827-352 944-90-76976:POH> <(07228:POH>) <서울특별시:LOC> <영등포구:LOC> <영신로 220 1408호:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <CSR팀:ORG> 방송작가 <황희풍:PER> Mobile : (+1)<810-7067-418 Site:POH> : <www.daedong-shop.co.kr Fax:POH> : (+<1)2722-490-881:POH> <Email : ki1xszpi[UNK]timj.co.kr:POH> <Tel ::POH> (+<1)64-8574-941:POH> <133-02-46460:POH> <(06349:POH>) <서울특별시:LOC> <강남구:LOC> <밤고개로1길 30:LOC> <4층:NOH>, <5층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  생활은 습관이 짜낸 천에 불과하다. 유목청년 <김승한:PER> 용병 정책실 <H ::POH> <www.roombyk.co.kr E : zj-1mlq5-v2[UNK]blueark.com:POH> <M : 991-127-385:POH> T : <044-185-3664:POH> <F : 8068-9586-445:POH> <(16573:POH>) <경기도:LOC> <수원시:LOC> <팔달구:LOC> <효원로 116:LOC> <신나라빌딩 1층 767-94-78920:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <플뢰르블랑:PER> 사람이 여행을 하는 것은 도착하기 위해서가 아니라 여행하기 위해서이다. 피미숙 정책실 임상병리사 팩스) <76-949-520:POH> 메일) <r_kt77[UNK]cosmdh.com:POH> 유선) <20-79-915:POH> 연락처) <144-427-4290:POH> 홈페이지) <www.iphonemarket.kr:POH> <208-16-74544:POH> <(06178:POH>) <서울특별시:LOC> <강남구:LOC> <삼성로86길 7:LOC> <삼성빌딩:LOC> <5층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <우리금융정보:POH> 열매를 맺지 않는 꽃은 심지 말고 의리 없는 친구는 사귀지 말라. <이재범:PER> 부품2팀 항공권예약발권사무원 메일. <4umwt_ow[UNK]bellboy.kr:POH> 팩스. (+503)<0485:NOH>.23.415 유선. (+503)15.0280.295 무선전화. (<+503:NOH>)<0287:DAT>.2995.0086 웹. <www.lohoseoul.com:POH> <544-91:POH>-449<22:DAT> <:LOC>(061<78:DAT>) <서울:LOC>특별시 <강남구:LOC> <삼성:LOC>로86길 <7:NOH>, <삼성:LOC>빌딩 <5층:NOH> <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <김승진:PER> 대리 대리점지원팀 <909-72-3090 561-358-633 2341-89-117:POH> <oc4yufqn[UNK]secogt.com:POH> <www.2sugardaddy.com:POH> <603-79-09513:POH> <(06149:POH>) <서울특별시:LOC> <강남구:LOC> <선릉로 541:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  장사를 하려면 가장 먼저 체면과 자존심을 버려라. 소소한가게 <녹색건축물인증심사원:ORG> <강신원:PER> 부품1팀 <Email:POH> : xq6h6mt3f[UNK]kolon.com Phone : (+675)<28.5978:NOH>.1900 <Tel:POH> : (+675)<5367:NOH>.37.214 <Web ::POH> <www.dakyungshoes.com:POH> <Fax:POH> : (+675)<6131:NOH>.65.994 <189:NOH>-20<-160:NOH>73 <:NOH>(32543) <충청:POH>남도 공주시 <백:POH>제<문화:POH><로:POH> <2148:NOH>-21 <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  행복이란 타인을 행복하게 해주려는 데서 생기는 부산물이다. <케이디에이치 코퍼레이션:ORG> CSR팀 <박현관:PER> 지역사회코디네이터 팩스 <74-579-857:POH> 이메일 <bhvrunw[UNK]aniverse.i:POH>o 연락처 <431-848-945:POH> 무선 <23-5680-798:POH> 홈페이지 <www.hellobat.com 795-59-34695 (06800:POH>) <서울특별시:LOC> <서초구:LOC> <헌릉로 176 601호:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  미미삼 아무것도 모르는 것이 수치가 아니라 아무 것도 배우려하지 않는 것이 수치다. <김진희:PER> 교수 노사협력팀 Email. <6u:NOH>7[UNK]<yakup.com:POH> Fax. (+<508:NOH>)<5664:NOH>.336.0965 Site. <www.josboardshop.com:POH> Mobile. (+<508:NOH>)<928:NOH>.90.3046 Tel. (+<508:NOH>)<8749:NOH>.449.2224 (06163) <서울특별시:LOC> <강남구:LOC> <삼성로 566:LOC> 4층 <508:NOH>-10-13172 <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <하이북코리아:ORG> 인생을 발전시키는 것은 그가 하고 있는 일이 아니라 그가 하고자 하는 일이다. 사업추진단 <김지수:PER> 외교관 P) <7847-688-559:POH> F) <290:POH>-49-411 T) <94-576-9548:POH> H) <winsystem.kr:POH> E) <83:POH>-4<yver[UNK]giowell.com:POH> (3<1188:DAT>) <충청남도:LOC> <천안시:LOC> <동남구:LOC> <광풍로 1859:LOC> <5층:NOH> <728-25-67389:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <쿠쿠스:ORG> 문제아 뒤에는 문제부모가 있다. <김형례:PER> 채권자산운용가 CSR팀 이메일) <b5vsoc:POH>[UNK]<mazars.kr:POH> 무선전화) (+92)6872-470-4549 연락처) (+92)515-00-966 팩스) (<+92:POH>)9441-74-262 사이트) <graziemama.co.kr:POH> <324-03-39641:NOH> <(06627:POH>) <서울특별시:LOC> <서초구:LOC> <강남대로 327:LOC> <6층:NOH>(<서초동:LOC>, 대륭<서:POH>초타워) <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  바닥나라 좋은 희망을 품는 것은 그것을 이룰 수 있는 지름길이다. <김남호:PER> 내부감사팀 목수 이메일. <tl1lsu_:POH>_f[UNK]<ifcns.co.kr:POH> 웹. <www.annancodi.com:POH> 무선. (<+62)8037-8559-864:POH> 팩스. <(:POH><+62)322-675-6700:POH> 연락처. (<+62)1294-508-374:POH> <356-92-64622:POH> <(08511:POH>) <서울특별시:LOC> <금천:LOC>구 <:POH>[UNK]<꽃:POH>로 278 <905호:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  내일에 아무런 도움이 되지 않는다면 , 당신의 과거는 쫓아버려라, <엘제이 마켓:ORG> <변영희:PER> 코치 테크센터 T) <2209-792-0170:POH> F) <0618-3875:POH>-311 P) <061-55-6659:POH> H) <www.puberty.co.kr:POH> E) <tj23pz0:POH>[UNK]<hotmail.net:POH> (04533) <서울특별시:LOC> <중구:LOC> <소공로 116:LOC> (<소공동:LOC>)<서울센터빌딩 14층 411-90:LOC>-29195 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <디엠컴퍼니:ORG> 사랑은 모든 시간을 재구성하고 모든 것을 새롭게 만든다. <심상우:PER> 인사팀 영화전문홍보가 <E w4uwepo-zkos[UNK]nver.com M 8503-4096-4616:POH> <F 3898-8076-533:POH> <H www.understood.co.kr:POH> <T 50-033-857:POH> <(06627:POH>) <서울특별시:LOC> <서초구:LOC> <강남대로 327 6층:LOC>(<서초동:LOC>, <대륭서초타워:LOC>) <542-91-46591:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  삶이 있는 한 희망은 있다. <인터넷마케팅센터:ORG> 과학에듀케이터 <김치선:PER> 재경팀 Tel : (+357)2360-31-034 <Web : www.noniplaza.co.kr Fax:POH> : (+357)<4302-5483:POH>-2207 <Email : kjn[UNK]nate.net Phone:POH> : (<+357:POH>)6928-71-050 (<0399:DAT>1) <서울특별시:LOC> <마포구:LOC> <월드컵북로 40:LOC> <스페이스원빌딩 3층:LOC> <505:NOH>-52-41328 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <이기정:PER> 파트장 부품1팀 Site. <www.partyat.co.kr P:POH>hone. (+995 34)5099-6113-2918 Fax. (+995 34)950-08-3377 <Email:POH>. <wzs4:POH>[UNK]<sjacc.co.kr:POH> Tel. (+995 34)587-69-8542 (13571) <경기도:LOC> <성남시:LOC> <분당구:LOC> <이매로 78-5:LOC> <이레빌딩 1층:LOC> <252-35-40355:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <피에스 유통:ORG> 사랑하며 가난한 것이 애정 없는 부유함 보다 훨씬 낫다. 화물차 기사 직판팀 <김현주:PER> Tel (+<32:NOH>)<9127:NOH>.2894.982 <Site www.getithealthy.co.kr:POH> Phone (<+32:NOH>)<087:NOH>.317.709 <Email a8u:POH>j2[UNK]<okkot.com Fax:POH> (+<32:NOH>)<8965:NOH>.4424.6643 (0<6194:NOH>) <서울특별시:LOC> <강남구:LOC> <삼성로85길 28:LOC> 우진빌딩 <003:NOH>-29-99<911:DAT> <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  오늘을 붙들어라! 되도록 내일에 의지하지 말라! <키드스텝 재료연구소:ORG> <라기욱:PER> 디지털마케터 M) <637:NOH>.89.190 F) <68:NOH>.1126.820 T) <184:NOH>.575.738 H) <www.myphotomap.co.kr:POH> E) <pj_jxbqqe2w:POH>[UNK]<academyx.co:POH> <305-69-02582:NOH> <(08511:POH>) <서울특별시:LOC> <금천구:LOC> <[UNK]꽃로 278 9:LOC>05호 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <스윗소이:POH> 게으름은 쇠붙이의 녹과 같다. 노동보다 더 심신을 소모시킨다. <보모:ORG> 회계팀 <박주연:PER> Fax. (+<49:NOH>)658-6650-8754 <Web. www.jimiholic.com:POH> Tel. (+<49:NOH>)38-7286-6823 <Email:POH>. <:POH>op26b3oi5d[UNK]eazysoft.kr <Mobile:POH>. (+<49:NOH>)<1418-8319-803:POH> (07665) <서울:LOC>특별시 <강:POH><서:POH><구:POH> <공항:POH>대로58<길:POH> <10:NOH> <19:POH>4-45-00137 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  실패는 잊어라 그러나 그것이 준 교훈은 절대 잊으면 안된다. <에스피파인:ORG> <전미진:PER> <ICT혁신단:ORG> 항해사 전화 : <350-94-372:POH> 홈페이지 : <www.marchenjewel.co.kr:POH> 연락처 : <372-97-099:POH> 메일 : <3qy6yg[UNK]yardin.com:POH> 팩스 : <957-4402-257:POH> <538-28-00784:POH> <(44616:POH>) <울산광역시:LOC> <남구:LOC> <대학로 13:LOC> <2층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <OK건설기계:ORG> 사랑은 달콤하다. 그러나 빵이 수반될 경우에만 그렇다. <전민선:PER> 아이디어컨설턴트 경영지원처 F (+963)<54:NOH>.72.155 <E pwg[UNK]bais.co.kr:POH> <H 건강앤미.com:POH> P (+963)<3083:NOH>.6842.408 T (<+96:POH>3)<4833:NOH>.5437.4876 <488:NOH>-39-83891 (06149) <서울특별시:LOC> <강남구:LOC> <선릉로 541:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  쿠폰자리 먼저핀꽃은 먼저진다 남보다 먼저 공을 세우려고 조급히 서둘것이 아니다 비행기 기장 <김형남:PER> 프로젝트팀 팩스 <1246-2822-174:POH> 사이트 <www.7universe.com:POH> 메일 <jd2jjqg[UNK]84lumber.kr:POH> 유선전화 <71-7934-2499:POH> 휴대폰 <4579-92-9491 (0624:POH>1) <서울특별시:LOC> <강남구:LOC> <강남대로 358 9:LOC>층 <062-43-77965:POH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <디지플러스:POH> 재능은 한계가 있지만 노력엔 한계가 없다. 회계팀 <엄혜선:PER> 서버프로그래머 휴대전화 : <8403:POH>.597.776 전자우편 : <1s8zbmpyj4s[UNK]ellucy.com:POH> 팩스 : <151.8661.171:POH> 사이트 : <www.sgmaru.com:POH> 유선전화 : <40.64.7729:NOH> (13571) <경기도:LOC> <성남시:LOC> <분당구:LOC> <이매로 78-5:LOC> <이레빌딩:LOC> <1층:NOH> <294-27-76431:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <이형철:PER> 연구소 애니메이션작가 유선전화 <059:POH>.448.8339 팩스 <74.142.0912:NOH> 이메일 <kksw6jgluv3[UNK]:POH><wiz.co.kr:POH> 웹 <www.charmmashdduk.com:POH> 휴대전화 <37.0176:POH>.086 (<04300:DAT>) <서울특별시:LOC> <용산구:LOC> <청파로 383:LOC> <1층:NOH> <480-26-41104:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <아이도로시:ORG> 더 좋은 것을 얻기 위해서는 좋은 것을 기꺼히 포기해야 한다. <친환경:ORG>병충해방제연구원 <조아름:PER> 사업추진단 M) (+358)<9133-0123-7519:POH> H) <bb0500:POH>.wgiga.co.kr T) (<+358)7626-32-9076:POH> F) (<+358)960-18-0640:POH> E) <n77k[UNK]gamil.com:POH> (06626) <서울특별시:LOC> <서초구:LOC> <서초대로74길 45:LOC> 5,<6층:NOH> <147:NOH>-89-60813 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <빅데이터부:ORG> <전아라:PER> 베타테스터 P : <436-88-7319:POH> <F : 239-378-9533:POH> <E : bphv[UNK]e2web.co.kr:POH> <H : www.bobos7.com:POH> <T : 891-8476-8157:POH> <846-28-60023:POH> <(06050:POH>) <서울특별시:LOC> <강남구:LOC> <언주로 725:LOC> 동관 2층 .
# --------------------------------------------------------------------------------------------------------
#
# output>  주로라이크 태만은 천천히 움직이므로 가난이 곧 따라 잡는다. 기술연구원 <김원민:PER> 노년플래너 <W:POH>eb. <www.러블봉봉.com:POH> Tel. (+64)920-7924-7510 Fax. (+64)76-94-093 Phone. (+64)3804-947-1261 <Email:POH>. <mfz4[UNK]:POH><teasung.com:POH> <(44616:POH>) <울산광역시:LOC> <남구:LOC> <대학로 13 2층 344-:LOC>34-42827 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <오복허브허브:POH>다이어트 세계와 나의 어머니를 저울질 한다면 세계 쪽이 훨씬 가벼울 것이다. 신발디자이너 전략기획실 <최진아:PER> 전화) <214:NOH>.32.7330 팩스) <23:NOH>.5293.2278 메일) _<7uj0:POH>p7<kwe[UNK]never.com:POH> 휴대전화) <972:DUR>.36.407 홈페이지) <:POH><parkingsystem.co.kr:POH> (0<6150:NOH>) <서울특별시:LOC> <강남구:LOC> <선릉로91길 10:LOC> <토탈스:ORG>위스빌딩 <535-79-53688:NOH> <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  위대한 사람들은 목적을, 소인들은 공상을 가지고 있다. 놀라운지 국제범죄전문가 자금팀 <송동민:PER> 웹 <sleepingbook.co.kr:POH> 유선전화 <4547-4837-7888:POH> 무선전화 <047-98-565:POH> 전자우편 <dn8unkga[UNK]winkia.net:POH> 팩스 <69-152-395 (06621:POH>) <서울특별시:LOC> <서초구:LOC> <강남대로 369:LOC> <에이플러스에셋타워:LOC> <8층 767-50-35853:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  지식은 나눌 수 있지만 지혜는 나눌 수 없다. <젬마홈:ORG> 노사협력팀 <김민재:PER> 커리어코치 <E : f7jeb5ayxbf[UNK]tnjcon.com H : www.aldebaran.co.kr:POH> <T : 83-466-7754:POH> <M : 92-8633-0458:POH> <F ::POH> <9137-8871-1260:POH> <(06236:POH>) <서울특별시:LOC> <강남구:LOC> <테헤란로22길 13:LOC> <7층:NOH>(<역삼동:LOC>, <예동빌딩:LOC>) <676-28:LOC>-54244 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  잔잔한 바다에서는 좋은 뱃사공이 만들어지지 않는다. <프롬핑퐁 부품1:ORG>팀 <제연선:PER> 의료관광코디네이터 <4062-69-426 805-7283-698 901-4621-2203:POH> <www.mymoon.co.kr:POH> <ulm2isw[UNK]hotmail.net:POH> <281-53-92052:POH> <(05804:POH>) <서울특별시:LOC> <송파구:LOC> <동남로 122:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  가장 귀중한 사람의 가치는 희생과 헌신이다. 주식회사 <디알에스:ORG> <신은:PER>선 금융자산관리사 <빅데이터부:ORG> E) <zx7[UNK]com35.com F:POH>) <582-25-1725:POH> T) <133-75-9397:POH> H) <www.dressj.co.kr P:POH>) <83-7693-516:POH> <(06164:POH>) <서울특별시:LOC> <강남구:LOC> <영동대로 517:LOC> (<삼성동:LOC>,<아셈타워:LOC>) <27:NOH>, <28:NOH>, <29층:NOH> <386-47-68252:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  좀 모자라는 사람은 말이 적은 바보일지 모르지만, 말 많은 바보보다는 낫다. 주식회사 <유비트에프엔비:ORG> <차상우:PER> 응급구조사 직판팀 <F 522-9542-8598:POH> <E b7vs[UNK]shinhan.com H www.blissfurnishing.com T 45-374-362:POH> <M 913-65-215:POH> <(10846:POH>) <경기도:LOC> <파주시:LOC> <탄현면:LOC> <축현산단로 56-16:LOC> (<축현리:LOC>) <551-12-89735:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <신도아트:ORG> 선도 그 때를 놓치면 소용이 없다. 푸드파이터 <이철기:PER> 경영지원처 Tel) (<+977:POH>)6669-1<49-937 Email:POH>) <ea6ffxa[UNK]onstn.com Web:POH>) <www.yuri-r.co.kr Phone:POH>) (<+977:POH>)<015-2596-349:NOH> <Fax:POH>) (<+977:POH>)5056-7435-7102 (08507) <서울특별시:LOC> <금천구:LOC> <가산디지털:LOC>1<로:LOC> <168:NOH> <A동:NOH> <1012호:NOH> <456-61:NOH>-16134 <:NOH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  기획1팀 무녀 <최애란:PER> <E : w_2tkyk6ml[UNK]hamac.co.kr:POH> <M : 5279-797-4362:POH> <T : 40-059-6789:POH> <F:POH> <: 90-69-855:POH> <H : www.Luzwave.com (06044:POH>) <서울특별:LOC>시 <강남구:LOC> <학동로3길 8:LOC> <환윤빌딩 1층:LOC> <785-33-54954:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  벤처캐피탈 성과관리처 <김지우:PER> <Fax:ORG>) <460-784:POH>-1<18:POH> <Site:POH>) <www.unclockwism.com Tel:POH>) <200-568-688 Phone:POH>) <24-12-8125:POH> <Email:ORG>) <ptwu0w[UNK]eudiny.com:POH> <285-14-79963:POH> <(06748:POH>) <서울특별시:LOC> <서초구:LOC> <바우뫼로 182 5층:LOC>(<양재동:LOC>, <에스앤씨빌딩:LOC>) .
# --------------------------------------------------------------------------------------------------------
#
# output>  넘버원 절대 어제를 후회하지 마라. 인생은 오늘의 나 안에 있고 내일은 스스로 만드는 것이다. <고은하:PER> 기술연구원 사서 Tel) (+290)<32-2943:POH>-014 Phone) (<+290:POH>)<8100:POH>-40-1<80:POH> <Em:POH>ail) <0uenpl:POH>_<nfbvw[UNK]kinexel.com:POH> <Web:POH>) <8949pc.com:POH> <Fax:POH>) (<+290:POH>)797-2824-1<71:NOH> <243:NOH>-79-09144 (05604) <서울:POH>특별시 <송:POH><파:POH>구 <백:POH>제고분로 <233:POH> <5층:NOH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <GOB:POH> 무엇보다도 너 자신에게 진실 하라! BJ <김영종:PER> 재경팀 핸드폰) (<+973:POH>)6921-7789-624 홈페이지) <www.somethingstory.com:POH> 팩스) (<+973:POH>)1924-266-4026 메일) <yw7pc[UNK]:POH><live.co.kr:POH> 유선) (<+973:POH>)487-477-1746 <(06060:POH>) <서울특별시:LOC> <강남구:LOC> <선릉로131길 15:LOC> <희승빌딩 7층 227:LOC>-12-65424 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  내일은 내일의 태양이 뜬다. <아이애:ORG> <정재균:PER> 음향엔지니어 상품계획팀 휴대전화 (<+376:POH>)4683-37-008 웹 <www.1st-island.co.kr:POH> 유선 (<+376:POH>)9026-77-572 이메일 <inw-lsgwj[UNK]kumone.kr:POH> 팩스 (<+376:POH>)5036-905-7353 <(06349:POH>) <서울특별시:LOC> <강남구:LOC> <밤고개로1길 30:LOC> <4층:NOH>, <5층:NOH> 046-96-63378 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  재능은 한계가 있지만 노력엔 한계가 없다. <고대:ORG> 기획 애견핸들러 테마파크 사업단 <김운기:PER> <3811-5337-299 983-067-8519:POH> <a4ckhoq[UNK]korea.kr:POH> <6490-1487-7602:POH> <www.tireking.co.kr:POH> <(06626:POH>) <서울특별:LOC>시 <서초구:LOC> <서초대로74길 45:LOC> <엔데버빌딩:LOC> 지하 1층 <272-52-54642:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  주식회사 <뉴톤이어닷컴:ORG> 나를 죽이지 못한 것은 끝내 나를 강하게 만들리라. <임명순:PER> 회계팀 대중무용수 <Web www.note9.com M:POH>obile 0961.840.5313 <Fax 52:POH>49.29.8906 <Email ew5[UNK]orionnet.kr:POH> <Tel:POH> <69:NOH>.650.6841 561-55-06221 <(47505:POH>) <부산광역시:LOC> <연제구:LOC> <중앙대로 1231:LOC> <에이스제이엠빌딩:LOC> <8층:NOH> .
# ...
#
# output>  준비에 실패하는 것은 실패를 준비하는 것이다. 기인생기 차 노사협력팀 오염지재개발전문가 <배우성:PER> 전자우편) <uyywmr1xs[UNK]hamac.co.kr:POH> 사이트) <www.soartokyo.co.kr:POH> 전화) <444-9782-6108:POH> 팩스) <975-619-555:POH> 연락처) <61-013-785:POH> <948-72-48760:POH> (06112) <서울특별시:LOC> <강남구:LOC> <학동로26길 23:LOC> <지오빌딩 4층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  불가능은 소심한 자의 환상이요, 비겁한 사람의 도피처이다. 더 <은진:PER> <강동희:PER> 집사 프로젝트팀 팩스. <2227-2948-6721:POH> 홈페이지. <www.sugargirl.kr:POH> 연락처. <6503-62-3451:POH> 유선전화. <0219-259-150:POH> 이메일. <8tyv_[UNK]nate4.com:POH> <300-40-33308:POH> <(04637:POH>) <서울특별:LOC>시 <중구:LOC> <후암로 110:LOC> <서울시티타워:LOC> <23층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  게임기획자 전산실 <김경연:PER> <Email:POH>. <bk7tlpc[UNK]agagen.com Web.:POH> <www.ongodangbook.co.kr:POH> Fax. <8499-94-0827:POH> <Phone:POH>. <08-2423-1695:POH> Tel. <235-4903-411 872-14-72772:POH> <(35229:POH>) <대전광역시:LOC> <서구:LOC> <둔지로 36:LOC> <4층:NOH> <404호:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  주식회사 <메디프런트:ORG> 인간은 의욕 하는 것 그리고 창조하는 것에 의해서 만이 행복하다. <양호준:PER> 프로젝트팀 프로기사 (+359)589-214-274 (<+359:POH>)95-517-093 <yekdqbm7mkad[UNK]beautyme.kr:POH> (<+359:POH>)910-9195-8858 <www.dadait.co.kr (06800:POH>) <서울특별시:LOC> <서초구:LOC> <헌릉로 176 601호 949-91-16572:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  인생에 뜻을 세우는데 있어 늦은 때라곤 없다 모델인 전산실 일러스트레이터 <김원주:PER> F. <75-95-1566:POH> T. <057-2007-3310:POH> P. <82-13-5565:POH> <E. f5knvzio[UNK]beraka.com:POH> <H. www.replmilano.com:POH> <403-24-16615 (0399:POH>1) <서울특별시:LOC> <마포구:LOC> <월드컵북로 40:LOC> <스페이스원빌딩:LOC> <3층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  고난의 한복판에 기회가 있다. <트윈라벨:ORG> 내부감사팀 기업컨시어지 DU GUANGCHENG Tel 909-536-7239 Mobile 544-42-3491 Site www.vintagecaptain.com Fax 261-3931-9816 <Email ektg[UNK]wwin.kr:POH> (54666) <전라북도:LOC> <익산시:LOC> <오산면 무왕로2길 262:LOC> 009-10-57392 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  반생이 지나서야 인생이 무엇인가를 알게 된다. <슈뱅크:ORG> <이재인:PER> 홀로그램디자이너 재경팀 Tel : <88:NOH>.2733.270 Phone : <691:NOH>.78.9253 <Email ::POH> -<n5s1[UNK]:NOH><heys.com Fax:POH> : <5277:NOH>.2525.961 <Site:POH> : <yesicaworld.com:POH> <828-34-84287:NOH> <(04539:NOH>) <서울특별시:LOC> <중구:LOC> <을지로 51 15층:LOC> (을지로2가, <교:LOC><원:POH>내외빌딩) <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  오랫동안 꿈을 그리는 사람은 마침내 그 꿈을 닮아간다. <다인커머스:ORG> <이재형:PER> 방송국PD 프로젝트팀 Phone : <05-725-4482:POH> Fax : <3241-5642-0075 Site ::POH> <www.kfde.co.kr Email : 3kgyut[UNK]nasun.net:POH> Tel : <46-89-763:POH> <(04539:POH>) <서울특별시:LOC> <중구:LOC> <을지로 51:LOC> <15층:NOH> (<을지로2가:LOC>, <교원내외빌딩:LOC>) <3:NOH>88-12-87758 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <테디파크:ORG> 아무리 유익한 책이라도 그 절반은 독자 자신에 의해서 만들어지는 것이다. <김유순:PER> 이미징사업팀 지점장 P : <62-9075-761:POH> <E : 2bl[UNK]kolon.com:POH> <F : 6409-64-670:POH> <H : itsteum.com:POH> <T ::POH> <06-3848-926:POH> <(06163:POH>) <서울특별시:LOC> <강남구:LOC> <삼성로 566 4층 470-15-08858:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  오늘 죽을 것처럼 행동하고 영원히 살 것처럼 배워라. <브루클린 YDP 소재연구소:ORG> <김성희:PER> 만화가 <E _u0lcnfdhk[UNK]preegia.com P 840-8177-293:POH> <H www.marue.co.kr:POH> <F 0074-38-9564:POH> <T 488-5375-9097:POH> <219-80-76981:POH> <(38891:POH>) <경상북도:LOC> <영천시:LOC> <금완로 47:LOC> <2층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  네가 가지고 있는 최선의 것을 세상에 주라. 그러면 최선의 것이 돌아오리라. <다온마켓:ORG> <윤채은:PER> 인재교육팀 토호 전자우편 : <y1tclxna4[UNK]agencyw.com:POH> 팩스 : <023:POH>.75.5578 연락처 : <8793.8543:POH>.316 휴대전화 : <6777:NOH>.3758.040 사이트 : <www.the-p.co.kr:POH> <172-16-77049:POH> <(06627:POH>) <서울특별시:LOC> <서초구:LOC> <강남대로 327 6:LOC>층(서초동, 대<륭:LOC>서초타워) <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  산다는 것은 호흡하는 것이 아니라 행동하는 일이다. <제이원:ORG> <이학진 테마파크 사업단:PER> 네트워크시스템분석가 T) <1529-6089:POH>-1<48:DAT> E) <jlfy[UNK]12font.com H:POH>) <www.blancrabbit.com F:POH>) <333-27-2248:POH> <M:POH>) <3639-76-629:POH> <(04637:POH>) <서울특별시:LOC> <중구:LOC> <후암로 110:LOC> <서울시티타워 23층 181-43-27628:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  이미끝나버린 일을 후회하기 보다는 하고 싶었던 일들을 하지못한 것을 후회하라. <우리랑벌룬:ORG> 경영지원처 산림치유지도사 <김종순:PER> <E 3eeulbtp21ma[UNK]artrank.net M 4686-4667-5299:POH> <H www.aesmedia.co.kr:POH> <F 14-44-277:POH> <T 66-57-940:POH> <(46918:POH>) <부산광역시:LOC> <사상구:LOC> <모라로 22:LOC> <부산벤처타워 415호:LOC> <862-91-21219:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  투투컴퓨터 장사를 하려면 가장 먼저 체면과 자존심을 버려라. <노동협력부:ORG> <박효정:PER> 식품기술자 <98-3418-9133 641-90-5634:POH> <wh27h[UNK]epal.com 10-609-809:POH> <www.keybuy.co.kr:POH> <(46918:POH>) <부산광역시:LOC> <사상구:LOC> <모라로 22:LOC> <부산벤처타워 415호 284-75-14162:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <로이라:PER> 마음이 좁은 자는 생각이 극단에 흐른다. <서커스:ORG> <박민준:PER> 마케팅팀 H. <fakemama.kr:POH> F. <7430-3244-267:POH> T. <76:POH>-11-1213 <E. hcvz_v--r[UNK]korea.ac.kr:POH> P. <523-659-6313:POH> <(06176:POH>) <서울특별시:LOC> <강남구:LOC> <테헤란로114길 38:LOC> <12층:NOH> <599-98-91495:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  잔잔한 바다에서는 좋은 뱃사공이 만들어지지 않는다. <코알:ORG> <김수현:PER> 인사팀 철도차량정비원 무선 <80-76-348:POH> 홈페이지 <www.seoultunehostel.com:POH> 이메일 <m4ccuxzlz[UNK]chichis.biz:POH> 팩스 29-47-733 유선전화 <557-247-6765:POH> <504-53-88349:POH> <(08507:POH>) <서울특별시:LOC> <금천구:LOC> <가산디지털1로 168 A동 1012호:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <티모아:ORG> 일하여 얻으라. 그러면 운명의 바퀴를 붙들어 잡은것이다 부사관 재경팀 <이선:PER>호 Fax : <1654.12.4019:DUR> <Site : www.origincell.co.kr:POH> <Tel : 991.885.3279:POH> <Email : sw0zhmgq[UNK]:POH><wibu.co.kr:POH> Phone : <066:DUR>.0913.673 <947-51-31773:POH> (41256) <대구광역시:LOC> <동구:LOC> <동대:LOC>구로 <503:POH> <신:POH><천동:POH> <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  신재정보시스템 나는 죽음을 겁내지 않는다. 다만 의무를 다하지 않고 사는 것을 겁낸다. 음악치료사 인사부 <김상미:PER> <Email : d83ivo[UNK]gamail.com Tel ::POH> <381.7553.350 Site ::NOH> <www.shoppop.kr Fax:POH> : <20.6252.742:NOH> <Phone:POH> : <096.0098.755:NOH> <335-23-94641:NOH> (06212) <서울특별시:LOC> <강남구:LOC> <테헤란로 328:LOC> <3층:NOH>(역삼동, <동우빌딩:LOC>) <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  <쿨앤핫코리아:ORG> 강인한 의지 없이는 뛰어난 재능도 필요없다. <김경선:PER> 테크센터 장관 E) <hbni03iv[UNK]ative.kr:POH> F) <1858:POH>-297-610 P) <69-46:POH>-441 T) <93-1074-6927:POH> H) <shop-interfran.co.kr:POH> (0<5556:POH>) <서울특별시:LOC> <송파구:LOC> <올림픽로 92:LOC> <3층:NOH> <426-11-94893:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  재물을 잃은 손실은 적지만 지혜를 잃은 손실은 크다. 스타일밍 <양성민:PER> 전략기획실 특수분장사 <Web www.newarrivalhomme.com Email 1tcpdvwgy8[UNK]scinco.com Phone 47-9700-1732:POH> <Tel 3334-18-8538:POH> <Fax 117-39-3010:POH> <(38891:POH>) <경상북도:LOC> <영천시:LOC> <금완로 47:LOC> <2층:NOH> <737-84-23434:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <드림디포:POH> 피할수 없으면 즐겨라. 경영기획팀 <라형철:PER> 리더십스타일리스트 H www.humannix.com F (+<64:NOH>)68-354-599 <E gk3ldbm[UNK]secogt.com:POH> M (+<64:POH>)74-09-961 T (+64)5656-14-239 <:POH>(06083) <서울특별시:LOC> <강남구:LOC> <봉은사로 619:LOC> <JBK타워:LOC> <4층:NOH>, <5층:NOH>, <6층:NOH>, <7층:NOH> <744-71-78973:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <베이시스트:ORG> <도레미:ORG> 전산실 <H. improvegift.co.kr:POH> F. <17-089-4610:POH> M. <192-854-1743:POH> T. <70-9605-2247:POH> <E. 28umbqxs2t[UNK]hanmial.net (06141):POH> <서울특별시:LOC> <강남구:LOC> <테헤란로 201:LOC> <18층:NOH> <517-90-79178:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  구제존 세상이라는 것은 거울이기 때문에 들여다보면 자기가 보인다. 무선사업부 제도사 <김대웅:PER> T (+<593:NOH>)<5447:NOH>.3412.6690 <H www.ehanatrv.com E :POH>lw08gf_<xoon7[UNK]ntom.co.kr:POH> M (+593)<24.46.568:NOH> F (+593)<48:NOH>.14.172 (0<6164:NOH>) <서울특별시:LOC> <강남구:LOC> <영동대로 511:LOC> <트레이드타워:LOC> <40층:NOH> <5호 170-97-7:NOH>6779 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  자신감 있는 표정을 지으면 자신감이 생긴다 <창창인터내셔날:ORG> 방문미용사 <길윤경:PER> 빅데이터부 전화. (+220)<190-7430:POH>-302 팩스. (+220)590-117-5830 휴대폰. (<+220:POH>)1369-2525-069 이메일. <hji0a382zf[UNK]empas.co.kr:POH> 사이트. <www.initium.kr:POH> <(14548:POH>) <경기도:LOC> <부천시:LOC> <중동로248번길 71 901:LOC>호 <883-82:POH>-18862 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  일과 오락이 규칙적으로 교대하면서 서로 조화를 이루면 생활이 즐거워진다. <원이씨:ORG> 제빵사 화학팀 <김년:PER> 유선. (+216)54-22-165 휴대폰. (<+216)751-56-988:POH> 팩스. (<+216)25-735-05:POH>66 웹. <www.월드레져.com:POH> 메일. <va0njul3ta3[UNK]:POH><ellucy.com:POH> <823-03-86799:POH> (12<128:NOH>) <경기도:LOC> <남양주:LOC>시 진건읍 독정로성지2길 <100:NOH> 엘라이프주식회사 <:POH>.
# --------------------------------------------------------------------------------------------------------
#
# output>  나무는 그 열매로 알려지고, 사람은 그 일로 평가된다. <인성무역:ORG> 영상및음성처리전문가 <이신영:PER> 교육연수팀 Phone. <752-22-2567:POH> Fax. <88-7397:POH>-3<25:POH> <Web. www.torigift.com Tel:POH>. <859-1514-4172:POH> <Email:POH>. <f7oap[UNK]9922.co.kr:POH> <(06236:POH>) <서울특별시:LOC> <강남구:LOC> <테헤란로22길 13:LOC> <7층:NOH>(<역삼동:LOC>, <예:LOC>동빌딩) <748-76-66464:LOC> <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  개발센터 <유빛누리:ORG> 발레리노 E. <eppp3[UNK]:POH><akc21.com:POH> T. (+264)791-89-053 F. (+264)2456-73-5654 P. (+264)20-335-378 H. <beautysoseek.com:POH> <156-66-58297:POH> <(41256:POH>) <대구광역시:LOC> <동구:LOC> <동대구로 503:LOC> <신천동:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  의욕적인 목표가 인생을 즐겁게 한다. <AJ정보통신:ORG> <나찬두:PER> 자금팀 상수도설계기술자 Fax) (+<1:NOH> <264:NOH>)<9806:NOH>.75.543 <Email:POH>) <2n:NOH>0c3bg[UNK]<icure.co.kr:POH> <Web:POH>) <www.sha-a.com Mobile:POH>) (+1 <264:NOH>)<21:NOH>.942.5<31:NOH> <T:POH>el) (+1 264)<39:NOH>.37.9562 <970-81-65681:NOH> (<0621:DAT>2) <서울특별:LOC>시 <강남구:LOC> <테:LOC><헤:LOC>란로 <328:NOH> <3층:NOH>(역삼동, <동우빌딩:LOC>) <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  안심하면서 먹는 한 조각의 빵이 근심하면서 먹는 잔치보다 낫다. 통신판매 요리사 법무팀 <이윤:PER>희 Fax) (+213)<7688-969-636:POH> Phone) (<+213:POH>)<008:POH>-09-8391 <Web:POH>) <www.mukimage.com Email:POH>) <cle[UNK]auur.in Tel:POH>) (<+213:POH>)<070-9193-0593:POH> <957-35-35513:POH> <(06164:POH>) 서울특별<시:POH> <강남구:LOC> <영동:LOC><대로:LOC> <517:POH> (<삼성동:LOC>,아셈타워) <27:POH>, <28:POH>, <29:POH>층 <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  여행은 정말 남는 장사이다. <SeBo 리사이클러 전지개발센터:ORG> <곽진일:PER> 팩스 : <819-31-008:POH> 무선전화 : <54-20-3178:POH> 메일 : <b7o5sif[UNK]092000.com:POH> 홈페이지 : <www.ingcom.kr:POH> 유선 : <774-0615-3735:POH> <(50839:POH>) <경상남도:LOC> <김해시:LOC> <활천로166번길 14:LOC> <2층:NOH> <529-02-47813:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <진우텔레콤:ORG> 신은 행동하지 않는 자는 결코 돕지 않는다. <최승무:PER> 비상기획관 미술품스페셜리스트 웹 <www.cncgroup.co.kr:POH> 메일 <1kwtn[UNK]mskshop.net:POH> 팩스 (<+39:POH>)4283.744.4127 휴대폰 (<+39)1669:POH>.2503.7931 연락처 (<+39:NOH>)<3476:NOH>.86.722 (07665) <서울특별시:LOC> <강서구:LOC> <공항대로58길 10 337-05-22895:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <앙고라:PER> <로라:PER> 아는 것을 안다하고, 모르는 것을 모른다하는 것이 말의 근본이다. 프로그래머 <최승열:PER> 전지개발센터 F (+681)399-63-5077 <M:POH> (+681)12-6615-4361 <E 1c:POH>_<dknvy4[UNK]84lumber.kr H www.arumtrend.com:POH> T (+681)005-30-0961 <(16506:POH>) <경기도:LOC> <수원시:LOC> <영통구:LOC> <센트럴타운로 114-8:LOC> <3층:NOH>(이의동, <농우바이오빌딩:POH>) <890-12-00741:NOH> <:LOC>.
# --------------------------------------------------------------------------------------------------------
#
# output>  정책실 <황재남:PER> 프런트 팩스) <53-19-5591:POH> 휴대전화) <11-4432-3956:POH> 전자우편) <z42m[UNK]blnprjt.com:POH> 전화) <36-043-304:POH> 사이트) <themade.kr:POH> <855-76-29710:POH> (41166) <대구광역시:LOC> <동구:LOC> <화랑로 471:LOC> (<용계동:LOC>) .
# --------------------------------------------------------------------------------------------------------
#
# output>  주식회사 <씨에스제이코리아:ORG> 금전, 쾌락 혹은 명예 좋아하는 사람은 남을 사랑하지 못한다. 통신서비스팀 <조은혜:PER> 모유영양분석가 <E:POH>. <4og13bilx[UNK]axis-xy.com:POH> P. <2285.07.4909:DUR> F. <71:POH>78.45.1828 T. <0:NOH>07.86.7085 <H:POH>. <www.happy-com.co.kr:POH> <348-69-25296 (0613:POH>2) <서울특별시:LOC> <강남구:LOC> <테헤란로 141 6층:LOC> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <서울모터스파츠:ORG> 말을 많이 하는 것과 말을 잘하는 것은 다르다. 정신대화사 <노동협력부:ORG> <정혜원:PER> 이메일 <6omgaf[UNK]gloseum.com:POH> 웹 <www.90shop.co.kr:POH> 유선전화 <7640.02:POH>.9723 팩스 <688:POH>.9515.3572 연락처 <694.888:POH>.180 <288-50-47880:POH> <(06178:POH>) <서울특별시:LOC> <강남구:LOC> <삼성로86길 7:LOC>, <삼성빌딩:LOC> <5층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <미토:PER> 행복한 사람에게는 시간을 알리는 소리가 들리지 않는다. 총무팀 <이하나:PER> <설서:PER>인 핸드폰 : (+<48:NOH>)<3686.3790.8117:NOH> 유선 : (+<48:NOH>)<3486.8144:NOH>.6432 홈페이지 : <www.귀요미베베.com:POH> 팩스 : (+<48:NOH>)7283.676.210 메일 : <6aownnwei6v[UNK]2424:POH>.com <102-76:NOH>-31907 (06181) <서울특별시:LOC> <강남구:LOC> <테헤란로 520:LOC> <8층:NOH>, <15층:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  오늘 달걀 <한 개:NOH> 갖는 것보다, 내인 암[UNK]을 <한 마리:NOH> 갖는 편이 낫다. <수담 직:ORG>판팀 연극놀이강사 <이형진:PER> 메일 <b6tjs-v[UNK]bitcd.com:POH> 무선전화 <6629-2565-403:POH> 유선 <5958-7852-499:POH> 홈페이지 <www.gbc.kr:POH> 팩스 2515-3504-429 (03991) <서울특별시:LOC> <마포구:LOC> <월드컵북로 40:LOC> <스페이스원빌딩:LOC> <3층:NOH> <604-06-66472:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  국제회의통역사 기획2팀 <최정태:PER> Phone) <378-932-2709:NOH> <Web:POH>) <www.eukom.co.kr Email:POH>) <2mowgqpf2w4:POH>z<[UNK]2ucare.com Tel:POH>) <51-2390-0323:POH> <Fax:POH>) <87-4667-20:POH>6 <:POH>(47505) <부산광역시:LOC> <연제구 중앙대로 1231:LOC> <에이스제이엠빌딩 8층:LOC> <398-36-38753:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <엔디에이시스템:ORG> 도중에 포기하지 말라. 망설이지 말라. 최후의 성공을 거둘 때까지 밀고 나가자. 사회복지사 연구소 <박순희:PER> F. <26-641-6721:POH> M. <8737-3601-7628:POH> T. <0063-26-7260:POH> E. <0zw0jfosc[UNK]:POH><smini.co.kr:POH> H. <www.verihenz.com:POH> <(04300:POH>) <서울특별시:LOC> <용산구:LOC> <청파로 383:LOC> <1층:NOH> <966-45-43391:NOH> .
# --------------------------------------------------------------------------------------------------------
#
# output>  <루엘리아:PER> 남을 따르는 법을 알지 못한 사람은 좋은 지도자가 될 수 없다. <천명화:ORG> 자금팀 헤드헌터 웹. <www.nextis.co.kr:POH> 유선전화. <299-9974-0352:POH> 팩스. <68-9162-837:POH> 무선전화. <1787-4565-780:POH> 메일. <y55l23l6w[UNK]:POH><turnway.com:POH> <(41166:POH>) <대구광역시:LOC> <동구:LOC> <화랑로 471:LOC> (<용계동:LOC>) <642-36-60:NOH>109 <:LOC>.
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# - 8개의 태그
#   - PER: 사람이름
#   - LOC: 지명
#   - ORG: 기관명
#   - POH: 기타
#   - DAT: 날짜
#   - TIM: 시간
#   - DUR: 기간
#   - MNY: 통화
#   - PNT: 비율
#   - NOH: 기타 수량표현

# %%
print("Num of Tags")
for tag in result.keys():
    print(f"{tag} : {len(result[tag])}")
# Out:
# Num of Tags
# PER : 540
# LOC : 1859
# ORG : 387
# POH : 3186
# DAT : 68
# TIM : 0
# DUR : 34
# MNY : 2
# PNT : 0
# NOH : 964

# %%
print('Example')
for tag in result.keys():
    print(f"{tag} : {result[tag][:50]}")
    # print(f"{tag} : {result[tag]}")
# Out:
# Example
# PER : ['서', '표용환', '김대성', '최우석', '박성희', '반한달', '윤정원', '김영도', '문정원', '이진형', '홍경문', '정규진', '이선유', '김한수', '이수경', '김준규', '그로스 앤 홀', '김현일', '김은진', '크린마스터', '김상균', '홍승정', '최은아', '오경수', '김인성', '이정림', '김규한', '최광희', '오순자', '강정수', '이지윤', '양서원', '정혜진', '김준석', '블링코', '김도전', '이누리', '유재원', '김재남', '김정연', '최은정', '임동근', '이용후', '서', '김기환', '김지숙', '윤솔비', '안상현', '김정호', '송영숙']
# LOC : ['서울특별시', '강남구', '테헤란로 329', '역삼동', '대전광역시', '서구', '충청남도', '공주시', '백제문화로 2148-21', '서울특별시', '강남구', '테헤란로 329 (', '삼동', '서울특별시', '강남구', '봉은사로112길 22 3층', '삼성동', '경상북도', '경주시', '외외1길', '서울특별시', '영등포구', '영신로 220 1408호', '서울특별시', '강서구', '등촌로55길 21', '서울특별시', '강남구', '테헤란로 328', '동우빌딩 10층', '서울특별시', '강남구', '선릉로 427', '서울특별시', '영등포구', '의사당대로 8 태', '서울특별', '강남구', '테헤란로 518 4층', '대치동', '서울특별시', '서대문구', '연희로 83', '은혜빌딩', '', '서울특별시', '송파구', '법원로 128 A동 408호 861-38-30081', '서울특별시', '송파구']
# ORG : ['제이준코스메틱', '큐온컴퍼니', '에스브이 컴퍼니', '헤이수', 'ICT혁신', '불링누리', '새론디자인', '샵마', '혜[UNK]틀연구소', 'Email', '수린산업', '에지리', '신한국인쇄소', '스타일로직 재료연구소', '법무사', '네일마트', 'Site www.thecodi.com Tel 134-794-705 Phone 37-401-2809', '빅데이터', '엣지컴퍼니', '노동협력부', '시아와', '로봇공연기획자 채권', '다인커머스 노동협력부', '', '엑스라이프', '에스 커', '트리니티 인터내셔널', '코스비즈', '한국글로벌', '이시아', '네오원', '삼미산업', '아', '도리도리클럽', 'e-Business팀', '쇼핑DS', '공구이마트', '노동협력부', 'CSR', 'e-Business팀', '맥주마이스터', '일성', '본디컴퍼니', 'e-Business', 'YQ신라', '한국유시티연구소', '수미트앤푸드', '녹색건축물인증심사원', '베리타스', '인더브라운 CSR팀']
# POH : ['www.irisgoodtour.com', 'uo6ay83k[UNK]', '4nsys.com', '+55', '+55', '+55', 'Web', 'www.tnyint.co.kr P', '+386', '623-88-5891 Fax', '+386)8111-2097-7085', 'Tel', '+386', '004-17-828', 'Email', '5rtrpk[UNK]', 'until.co.kr', '로', '', 'www.necktiehouse.com E. feid[UNK]ikgia.com', '15-1488-4422', '016-1950-271', '6615-89-200', '119-07-28945', '(32543', 'khdbnql6[UNK]', 'epntec.com Fax', '43-816-707', 'Web. www.edupangpang.co.kr', 'M', '635-91-8443', '5220-662-256', '1215호', '5112-13-8068', '1123-7898-9961', '688-75', 'c1j6a[UNK]hanmail.net', 'mizcolor.com', 'i6jdlb3ig[UNK]acecode.kr', '263-3013', '938-789-0259', 'www.v-violin.com', '44-8741-317 650-09-81000', '(38065', '2층', '', ' 9361-77-7612', ' 6i5i52blf[UNK]beosome.com', ' 6235-725-3255', ' 392-816-6503']
# DAT : ['(', '0617', '10', '11', '0621', '30', '0846', '86', '24', '9029', '62', '1256', '02', '03호', '0618', '0287', '22', '78', '1188', '0399', '911', '04300', '17', '12.3712.1377', '0621', '28', '22', '04300', '19', '17', '06', '0585', '0614', '23', '24', '90', '08', '0846', '(', '0399', '0614', '37', '2080', '18', '0621', '7505', '23', '0585', '09.3790', '0614']
# TIM : []
# DUR : ['15분', '15분', '502-1408-225', '27-114', '8620.58.0947', '78', '972', '18.3277.1377', '9517.87.9629', '5266.40.8403', '7', '2층', '9615.658.3135', '582.26.305', '31.925', '38-145-409', '(03991)', '017.31.824', '16.2910.444', '79.70.5970', '779.03.1908', '02', '78.08.1910', '8065', '46.17.791', '190.604.6618', '03.386.448', '877-351-459', '39.01.201', '095.046.3795', '35.6858.6436', '1654.12.4019', '066', '2285.07.4909']
# MNY : ['(06025', '(06236']
# PNT : []
# NOH : ['830', '', '5229', '36', '4층', '404호', '619', '(06150', '355-17-01054', '', '440-75-51519', '4층 691-68-87784', '652.6297.609', '17.43.8404 (06212)', '13층', '578-23-58941', '한 개', '한 마리', '5854', '185-68-67099', '지하1', '지상1', '지', '3층', '14.41', '896', '92.5', '936', '3층', '910-23-24666', '20층', '1호 478-78', '7층', '8층', '801호', '6층', '4', '4층', '5층', '2793-17', '2층', '1 809', '3306', '3층', '8층 801호', '256-70', '2층', '204', '212호', '561-85-46444']
